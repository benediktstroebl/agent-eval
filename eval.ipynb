# %%
import json
from typing import Dict, List, Tuple
import statistics
import matplotlib.pyplot as plt

model_prices = {
    "gpt-3.5-turbo-1106": {"prompt": 0.5/1000000, "completion": 1.5/1000000},
    "gpt-3.5-turbo-0613": {"prompt": 0.5/1000000, "completion": 1.5/1000000},
    "azure_gpt-35-turbo-0613": {"prompt": 0.5/1000000, "completion": 1.5/1000000},
    "gpt-4-turbo-2024-04-09": {"prompt": 10/1000000, "completion": 30/1000000},
    "gpt-4-1106-preview": {"prompt": 10/1000000, "completion": 30/1000000},
    "gpt-4-0125": {"prompt": 10/1000000, "completion": 30/1000000},
    "gpt-3.5-turbo-0125": {"prompt": 0.5/1000000, "completion": 1.5/1000000},  # Add prices for other models
    "gpt-35-turbo": {"prompt": 0.5/1000000, "completion": 1.5/1000000},  # Add prices for other models
    "codellama/CodeLlama-34b-Instruct-hf": {"prompt": 0.776/1000000, "completion": 0.776/1000000},
    "gpt-4-0613": {"prompt": 30/1000000, "completion": 60/1000000},
    'meta-llama/Llama-3-8b-chat-hf': {"prompt": 0.2/1000000, "completion": 0.2/1000000},
    'meta-llama/Llama-3-70b-chat-hf': {"prompt": 0.9/1000000, "completion": 0.9/1000000},
    "azure-agent-eval-gpt-4": {"prompt": 10/1000000, "completion": 30/1000000},
    "azure_gpt-4-0613": {"prompt": 30/1000000, "completion": 60/1000000},
}

def analyze_log(log_file: str) -> Tuple[Dict[str, float], List[Dict[str, float]]]:
    """Analyzes a log file containing OpenAI API call data.

    Args:
        log_file: The path to the log file.

    Returns:
        A tuple containing two dictionaries:
            - aggregate_stats: A dictionary containing aggregate statistics for the entire run.
            - per_task_stats: A list of dictionaries, each containing statistics for a single task.
    """

    with open(log_file, 'r') as f:
        log_data = [json.loads(line) for line in f]

    aggregate_stats = {
        'total_time': 0.0,
        'total_inference_time': 0.0,
        'total_prompt_tokens': 0,
        'total_completion_tokens': 0,
        'total_tasks': 0,
        'total_cost': 0.0,
        'average_task_time': 0.0,
        'average_inference_time': 0.0,
        'average_prompt_tokens': 0.0,
        'average_completion_tokens': 0.0
    }
    per_task_stats = []
    # Lists to store metrics for calculating min, max, and stddev
    task_times = []
    inference_times = []
    prompt_tokens = []
    completion_tokens = []

    current_task_id = None  # Keep track of the current task ID
    for entry in log_data:
        try:
            type = entry['type']
        except:
            continue
        if entry['type'] == 'task_started':
            task_stats = {
                'task_id': entry['task_id'],
                'task_time': 0.0,  # Initialize task time
                'total_inference_time': 0.0,
                'cost': 0.0,
                'prompt_tokens': 0,
                'completion_tokens': 0,
                'total_tokens':0
            }
            per_task_stats.append(task_stats)
            current_task_id = entry['task_id']  # Update current task ID
        elif entry['type'] == 'task_finished':
            for task in per_task_stats:
                if task['task_id'] == entry['task_id']:
                    task['task_time'] = entry['task_time']  # Update task time
                    aggregate_stats['total_time'] += entry['task_time']
                    aggregate_stats['total_tasks'] += 1
                    break  
            current_task_id = None  # Reset current task ID
        elif entry['type'] == 'api_call':
            # Find the task based on the current_task_id
            for task in per_task_stats:
                if task['task_id'] == current_task_id:
                    task['total_inference_time'] += entry['inference_time']
                    task['prompt_tokens'] += entry['prompt_tokens']
                    task['completion_tokens'] += entry['completion_tokens']
                    task['total_tokens'] += entry['completion_tokens'] + entry['prompt_tokens']
                    task['cost'] += entry['prompt_tokens'] * model_prices[entry['model_name']]['prompt'] + entry['completion_tokens'] * model_prices[entry['model_name']]['completion']
                    aggregate_stats['total_inference_time'] += entry['inference_time']
                    aggregate_stats['total_prompt_tokens'] += entry['prompt_tokens']
                    aggregate_stats['total_completion_tokens'] += entry['completion_tokens']
                    aggregate_stats['total_cost'] += entry['prompt_tokens'] * model_prices[entry['model_name']]['prompt'] + entry['completion_tokens'] * model_prices[entry['model_name']]['completion']
                    break 
        elif entry['type'] == 'run_finished':
            aggregate_stats['accuracy'] = entry['accuracy']

    aggregate_stats['average_task_time'] = aggregate_stats['total_time'] / aggregate_stats['total_tasks']
    aggregate_stats['average_inference_time'] = aggregate_stats['total_inference_time'] / aggregate_stats['total_tasks']
    aggregate_stats['average_prompt_tokens'] = aggregate_stats['total_prompt_tokens'] / aggregate_stats['total_tasks']
    aggregate_stats['average_completion_tokens'] = aggregate_stats['total_completion_tokens'] / aggregate_stats['total_tasks']

    # Calculate min, max, and stddev for aggregate stats from per_task_stats
    task_times = [task['task_time'] for task in per_task_stats]
    inference_times = [task['total_inference_time'] for task in per_task_stats]
    prompt_tokens = [task['prompt_tokens'] for task in per_task_stats]
    completion_tokens = [task['completion_tokens'] for task in per_task_stats]
    total_tokens = [task['prompt_tokens']+task['completion_tokens'] for task in per_task_stats]
    total_cost = [task['cost'] for task in per_task_stats]

    # Calculate min, max, and stddev for aggregate stats
    aggregate_stats['min_cost'] = min(total_cost)
    aggregate_stats['max_cost'] = max(total_cost)
    aggregate_stats['stddev_cost'] = statistics.stdev(total_cost)

    # Calculate min, max, and stddev for aggregate stats
    aggregate_stats['min_task_time'] = min(task_times)
    aggregate_stats['max_task_time'] = max(task_times)
    aggregate_stats['stddev_task_time'] = statistics.stdev(task_times)

    aggregate_stats['min_inference_time'] = min(inference_times)
    aggregate_stats['max_inference_time'] = max(inference_times)
    aggregate_stats['stddev_inference_time'] = statistics.stdev(inference_times)
    # median inference time
    aggregate_stats['median_inference_time'] = statistics.median(inference_times)

    aggregate_stats['min_prompt_tokens'] = min(prompt_tokens)
    aggregate_stats['max_prompt_tokens'] = max(prompt_tokens)
    aggregate_stats['stddev_prompt_tokens'] = statistics.stdev(prompt_tokens)

    aggregate_stats['min_completion_tokens'] = min(completion_tokens)
    aggregate_stats['max_completion_tokens'] = max(completion_tokens)
    aggregate_stats['stddev_completion_tokens'] = statistics.stdev(completion_tokens)

    aggregate_stats['min_total_tokens'] = min(total_tokens)
    aggregate_stats['max_total_tokens'] = max(total_tokens)
    aggregate_stats['stddev_total_tokens'] = statistics.stdev(total_tokens)

    return aggregate_stats, per_task_stats

# Example usage:
if __name__ == '__main__':
    aggregate_stats, per_task_stats = analyze_log('LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-3.5-turbo-0613/run1/humaneval-py._mcts_gpt-3.5-turbo-0613.log')
    print("Aggregate Statistics:")
    print(aggregate_stats)
    print("\nPer-Task Statistics:")
    for task_stats in per_task_stats:
        print(task_stats)
# Out:
# Aggregate Statistics:
# {'total_time': 93959.87075972557, 'total_inference_time': 45037.74848604202, 'total_prompt_tokens': 13963759, 'total_completion_tokens': 1324674, 'total_tasks': 163, 'total_cost': 8.968890500000024, 'average_task_time': 576.4409249062918, 'average_inference_time': 276.3052054358406, 'average_prompt_tokens': 85667.23312883436, 'average_completion_tokens': 8126.834355828221, 'accuracy': 0.774390243902439, 'min_cost': 0.0003035, 'max_cost': 0.20523950000000002, 'stddev_cost': 0.05994940669389553, 'min_task_time': 0.8675825595855713, 'max_task_time': 5122.468677282333, 'stddev_task_time': 916.4591945394498, 'min_inference_time': 0.8654859066009521, 'max_inference_time': 2474.907593011856, 'stddev_inference_time': 417.83385872429784, 'median_inference_time': 65.34215641021729, 'min_prompt_tokens': 349, 'max_prompt_tokens': 297001, 'stddev_prompt_tokens': 93764.33440408784, 'min_completion_tokens': 77, 'max_completion_tokens': 37826, 'stddev_completion_tokens': 8859.550321102404, 'min_total_tokens': 435, 'max_total_tokens': 334827, 'stddev_total_tokens': 102450.43756687213}
#
# Per-Task Statistics:
# {'task_id': 'HumanEval_23_strlen', 'task_time': 191.65738940238953, 'total_inference_time': 191.4053292274475, 'cost': 0.09838, 'prompt_tokens': 160895, 'completion_tokens': 11955, 'total_tokens': 172850}
# {'task_id': 'HumanEval_89_encrypt', 'task_time': 268.4751160144806, 'total_inference_time': 268.1043481826782, 'cost': 0.11770999999999997, 'prompt_tokens': 181084, 'completion_tokens': 18112, 'total_tokens': 199196}
# {'task_id': 'HumanEval_95_check_dict_case', 'task_time': 30.324588775634766, 'total_inference_time': 30.291110515594482, 'cost': 0.018278, 'prompt_tokens': 29620, 'completion_tokens': 2312, 'total_tokens': 31932}
# {'task_id': 'HumanEval_85_add', 'task_time': 164.54575037956238, 'total_inference_time': 164.18066000938416, 'cost': 0.10880249999999997, 'prompt_tokens': 177783, 'completion_tokens': 13274, 'total_tokens': 191057}
# {'task_id': 'HumanEval_140_fix_spaces', 'task_time': 193.35426592826843, 'total_inference_time': 192.98261189460754, 'cost': 0.12024850000000002, 'prompt_tokens': 189686, 'completion_tokens': 16937, 'total_tokens': 206623}
# {'task_id': 'HumanEval_63_fibfib', 'task_time': 2.729794979095459, 'total_inference_time': 2.726484775543213, 'cost': 0.000541, 'prompt_tokens': 557, 'completion_tokens': 175, 'total_tokens': 732}
# {'task_id': 'HumanEval_151_double_the_difference', 'task_time': 1.655623435974121, 'total_inference_time': 1.6527493000030518, 'cost': 0.00043349999999999997, 'prompt_tokens': 531, 'completion_tokens': 112, 'total_tokens': 643}
# {'task_id': 'HumanEval_22_filter_integers', 'task_time': 8.746495485305786, 'total_inference_time': 8.724853515625, 'cost': 0.0050725, 'prompt_tokens': 7502, 'completion_tokens': 881, 'total_tokens': 8383}
# {'task_id': 'HumanEval_41_car_race_collision', 'task_time': 63.96347379684448, 'total_inference_time': 63.89913058280945, 'cost': 0.024615499999999995, 'prompt_tokens': 28702, 'completion_tokens': 6843, 'total_tokens': 35545}
# {'task_id': 'HumanEval_17_parse_music', 'task_time': 3.266775131225586, 'total_inference_time': 3.2635037899017334, 'cost': 0.0008805, 'prompt_tokens': 597, 'completion_tokens': 388, 'total_tokens': 985}
# {'task_id': 'HumanEval_79_decimal_to_binary', 'task_time': 1.584380865097046, 'total_inference_time': 1.5820121765136719, 'cost': 0.000513, 'prompt_tokens': 537, 'completion_tokens': 163, 'total_tokens': 700}
# {'task_id': 'HumanEval_14_all_prefixes', 'task_time': 1.5501186847686768, 'total_inference_time': 1.5480854511260986, 'cost': 0.0003595, 'prompt_tokens': 371, 'completion_tokens': 116, 'total_tokens': 487}
# {'task_id': 'HumanEval_53_add', 'task_time': 0.8675825595855713, 'total_inference_time': 0.8654859066009521, 'cost': 0.000316, 'prompt_tokens': 365, 'completion_tokens': 89, 'total_tokens': 454}
# {'task_id': 'HumanEval_159_eat', 'task_time': 49.84237766265869, 'total_inference_time': 49.77070450782776, 'cost': 0.03282499999999999, 'prompt_tokens': 52303, 'completion_tokens': 4449, 'total_tokens': 56752}
# {'task_id': 'HumanEval_115_max_fill', 'task_time': 239.2586760520935, 'total_inference_time': 238.96348595619202, 'cost': 0.1417449999999999, 'prompt_tokens': 213950, 'completion_tokens': 23180, 'total_tokens': 237130}
# {'task_id': 'HumanEval_160_do_algebra', 'task_time': 1891.2649099826813, 'total_inference_time': 740.9628880023956, 'cost': 0.15998150000000003, 'prompt_tokens': 234910, 'completion_tokens': 28351, 'total_tokens': 263261}
# {'task_id': 'HumanEval_27_flip_case', 'task_time': 17.0800621509552, 'total_inference_time': 4.840061664581299, 'cost': 0.0003035, 'prompt_tokens': 349, 'completion_tokens': 86, 'total_tokens': 435}
# {'task_id': 'HumanEval_105_by_length', 'task_time': 1460.711659669876, 'total_inference_time': 707.1573991775513, 'cost': 0.14312799999999998, 'prompt_tokens': 222434, 'completion_tokens': 21274, 'total_tokens': 243708}
# {'task_id': 'HumanEval_25_factorize', 'task_time': 24.57106852531433, 'total_inference_time': 15.800887107849121, 'cost': 0.000539, 'prompt_tokens': 505, 'completion_tokens': 191, 'total_tokens': 696}
# {'task_id': 'HumanEval_96_count_up_to', 'task_time': 138.52103114128113, 'total_inference_time': 65.34215641021729, 'cost': 0.006021499999999999, 'prompt_tokens': 7807, 'completion_tokens': 1412, 'total_tokens': 9219}
# {'task_id': 'HumanEval_34_unique', 'task_time': 19.659366846084595, 'total_inference_time': 13.034736394882202, 'cost': 0.0005200000000000001, 'prompt_tokens': 419, 'completion_tokens': 207, 'total_tokens': 626}
# {'task_id': 'HumanEval_74_total_match', 'task_time': 19.418647527694702, 'total_inference_time': 10.396245956420898, 'cost': 0.0006284999999999999, 'prompt_tokens': 669, 'completion_tokens': 196, 'total_tokens': 865}
# {'task_id': 'HumanEval_35_max_element', 'task_time': 20.69906258583069, 'total_inference_time': 11.039838790893555, 'cost': 0.00042, 'prompt_tokens': 435, 'completion_tokens': 135, 'total_tokens': 570}
# {'task_id': 'HumanEval_132_is_nested', 'task_time': 1592.238450050354, 'total_inference_time': 765.1672942638397, 'cost': 0.10139650000000003, 'prompt_tokens': 157286, 'completion_tokens': 15169, 'total_tokens': 172455}
# {'task_id': 'HumanEval_103_rounded_avg', 'task_time': 20.789851188659668, 'total_inference_time': 15.137204647064209, 'cost': 0.0016430000000000001, 'prompt_tokens': 571, 'completion_tokens': 905, 'total_tokens': 1476}
# {'task_id': 'HumanEval_113_odd_count', 'task_time': 945.3706839084625, 'total_inference_time': 472.02741408348083, 'cost': 0.13121349999999996, 'prompt_tokens': 204251, 'completion_tokens': 19392, 'total_tokens': 223643}
# {'task_id': 'HumanEval_109_move_one_ball', 'task_time': 140.5369861125946, 'total_inference_time': 65.23743867874146, 'cost': 0.0076975, 'prompt_tokens': 10934, 'completion_tokens': 1487, 'total_tokens': 12421}
# {'task_id': 'HumanEval_107_even_odd_palindrome', 'task_time': 1585.1250441074371, 'total_inference_time': 720.4663419723511, 'cost': 0.12194899999999997, 'prompt_tokens': 188395, 'completion_tokens': 18501, 'total_tokens': 206896}
# {'task_id': 'HumanEval_138_is_equal_to_sum_even', 'task_time': 26.80853796005249, 'total_inference_time': 15.441428422927856, 'cost': 0.001356, 'prompt_tokens': 423, 'completion_tokens': 763, 'total_tokens': 1186}
# {'task_id': 'HumanEval_62_derivative', 'task_time': 1414.5021131038666, 'total_inference_time': 587.6960952281952, 'cost': 0.09437450000000001, 'prompt_tokens': 157105, 'completion_tokens': 10548, 'total_tokens': 167653}
# {'task_id': 'HumanEval_126_is_sorted', 'task_time': 1165.712028503418, 'total_inference_time': 562.4146304130554, 'cost': 0.08255950000000002, 'prompt_tokens': 124709, 'completion_tokens': 13470, 'total_tokens': 138179}
# {'task_id': 'HumanEval_161_solve', 'task_time': 199.41788482666016, 'total_inference_time': 98.45704555511475, 'cost': 0.012683999999999999, 'prompt_tokens': 20091, 'completion_tokens': 1759, 'total_tokens': 21850}
# {'task_id': 'HumanEval_130_tri', 'task_time': 1923.182322025299, 'total_inference_time': 812.6827900409698, 'cost': 0.13396399999999994, 'prompt_tokens': 211915, 'completion_tokens': 18671, 'total_tokens': 230586}
# {'task_id': 'HumanEval_36_fizz_buzz', 'task_time': 3213.2118871212006, 'total_inference_time': 933.0663778781891, 'cost': 0.1165865, 'prompt_tokens': 182839, 'completion_tokens': 16778, 'total_tokens': 199617}
# {'task_id': 'HumanEval_29_filter_by_prefix', 'task_time': 21.75766658782959, 'total_inference_time': 11.701560258865356, 'cost': 0.0005405, 'prompt_tokens': 427, 'completion_tokens': 218, 'total_tokens': 645}
# {'task_id': 'HumanEval_84_solve', 'task_time': 2051.932780981064, 'total_inference_time': 837.4898674488068, 'cost': 0.11045449999999997, 'prompt_tokens': 179203, 'completion_tokens': 13902, 'total_tokens': 193105}
# {'task_id': 'HumanEval_129_minPath', 'task_time': 1675.755860567093, 'total_inference_time': 753.3821930885315, 'cost': 0.20523950000000002, 'prompt_tokens': 297001, 'completion_tokens': 37826, 'total_tokens': 334827}
# {'task_id': 'HumanEval_98_count_upper', 'task_time': 1257.8869426250458, 'total_inference_time': 525.2860419750214, 'cost': 0.11020199999999998, 'prompt_tokens': 174609, 'completion_tokens': 15265, 'total_tokens': 189874}
# {'task_id': 'HumanEval_120_maximum', 'task_time': 812.1953740119934, 'total_inference_time': 341.89433097839355, 'cost': 0.08913449999999995, 'prompt_tokens': 140913, 'completion_tokens': 12452, 'total_tokens': 153365}
# {'task_id': 'HumanEval_24_largest_divisor', 'task_time': 14.868762493133545, 'total_inference_time': 8.327492713928223, 'cost': 0.0004065, 'prompt_tokens': 357, 'completion_tokens': 152, 'total_tokens': 509}
# {'task_id': 'HumanEval_88_sort_array', 'task_time': 87.64398789405823, 'total_inference_time': 45.1492977142334, 'cost': 0.011441, 'prompt_tokens': 17086, 'completion_tokens': 1932, 'total_tokens': 19018}
# {'task_id': 'HumanEval_106_f', 'task_time': 133.93581128120422, 'total_inference_time': 60.87423086166382, 'cost': 0.012681999999999999, 'prompt_tokens': 19592, 'completion_tokens': 1924, 'total_tokens': 21516}
# {'task_id': 'HumanEval_77_iscube', 'task_time': 502.08037209510803, 'total_inference_time': 215.27012157440186, 'cost': 0.051813500000000005, 'prompt_tokens': 82831, 'completion_tokens': 6932, 'total_tokens': 89763}
# {'task_id': 'HumanEval_93_encode', 'task_time': 1310.6821427345276, 'total_inference_time': 607.4053871631622, 'cost': 0.140748, 'prompt_tokens': 213498, 'completion_tokens': 22666, 'total_tokens': 236164}
# {'task_id': 'HumanEval_91_is_bored', 'task_time': 1047.2596683502197, 'total_inference_time': 477.1733729839325, 'cost': 0.10056350000000003, 'prompt_tokens': 151846, 'completion_tokens': 16427, 'total_tokens': 168273}
# {'task_id': 'HumanEval_43_pairs_sum_to_zero', 'task_time': 14.58661675453186, 'total_inference_time': 8.719399213790894, 'cost': 0.000494, 'prompt_tokens': 589, 'completion_tokens': 133, 'total_tokens': 722}
# {'task_id': 'HumanEval_71_triangle_area', 'task_time': 15.496397018432617, 'total_inference_time': 9.888978958129883, 'cost': 0.0006515, 'prompt_tokens': 517, 'completion_tokens': 262, 'total_tokens': 779}
# {'task_id': 'HumanEval_148_bf', 'task_time': 1202.849535226822, 'total_inference_time': 525.2956354618073, 'cost': 0.14300399999999996, 'prompt_tokens': 217428, 'completion_tokens': 22860, 'total_tokens': 240288}
# {'task_id': 'HumanEval_131_digits', 'task_time': 82.95092463493347, 'total_inference_time': 35.07612133026123, 'cost': 0.005559499999999999, 'prompt_tokens': 7606, 'completion_tokens': 1171, 'total_tokens': 8777}
# {'task_id': 'HumanEval_101_words_string', 'task_time': 13.756652593612671, 'total_inference_time': 7.100419044494629, 'cost': 0.000464, 'prompt_tokens': 511, 'completion_tokens': 139, 'total_tokens': 650}
# {'task_id': 'HumanEval_18_how_many_times', 'task_time': 194.62428069114685, 'total_inference_time': 76.49502778053284, 'cost': 0.0243045, 'prompt_tokens': 37983, 'completion_tokens': 3542, 'total_tokens': 41525}
# {'task_id': 'HumanEval_137_compare_one', 'task_time': 973.9288923740387, 'total_inference_time': 439.4850239753723, 'cost': 0.13728999999999994, 'prompt_tokens': 204047, 'completion_tokens': 23511, 'total_tokens': 227558}
# {'task_id': 'HumanEval_51_remove_vowels', 'task_time': 13.628610849380493, 'total_inference_time': 5.7576422691345215, 'cost': 0.000379, 'prompt_tokens': 461, 'completion_tokens': 99, 'total_tokens': 560}
# {'task_id': 'HumanEval_70_strange_sort_list', 'task_time': 12.455495834350586, 'total_inference_time': 8.22156834602356, 'cost': 0.000536, 'prompt_tokens': 529, 'completion_tokens': 181, 'total_tokens': 710}
# {'task_id': 'HumanEval_20_find_closest_elements', 'task_time': 1355.0438203811646, 'total_inference_time': 602.8861927986145, 'cost': 0.14714349999999993, 'prompt_tokens': 235541, 'completion_tokens': 19582, 'total_tokens': 255123}
# {'task_id': 'HumanEval_76_is_simple_power', 'task_time': 1000.6703689098358, 'total_inference_time': 414.2636065483093, 'cost': 0.11652299999999997, 'prompt_tokens': 182697, 'completion_tokens': 16783, 'total_tokens': 199480}
# {'task_id': 'HumanEval_39_prime_fib', 'task_time': 237.84402799606323, 'total_inference_time': 97.27123308181763, 'cost': 0.019900499999999998, 'prompt_tokens': 30135, 'completion_tokens': 3222, 'total_tokens': 33357}
# {'task_id': 'HumanEval_145_order_by_points', 'task_time': 1334.950845003128, 'total_inference_time': 587.5563004016876, 'cost': 0.13385049999999998, 'prompt_tokens': 212015, 'completion_tokens': 18562, 'total_tokens': 230577}
# {'task_id': 'HumanEval_0_has_close_elements', 'task_time': 104.61621952056885, 'total_inference_time': 45.4072847366333, 'cost': 0.006089, 'prompt_tokens': 8647, 'completion_tokens': 1177, 'total_tokens': 9824}
# {'task_id': 'HumanEval_10_make_palindrome', 'task_time': 326.29489612579346, 'total_inference_time': 139.03584146499634, 'cost': 0.028135999999999998, 'prompt_tokens': 42796, 'completion_tokens': 4492, 'total_tokens': 47288}
# {'task_id': 'HumanEval_11_string_xor', 'task_time': 19.525776386260986, 'total_inference_time': 14.06401515007019, 'cost': 0.00044950000000000003, 'prompt_tokens': 395, 'completion_tokens': 168, 'total_tokens': 563}
# {'task_id': 'HumanEval_139_special_factorial', 'task_time': 1559.0582826137543, 'total_inference_time': 682.8296756744385, 'cost': 0.12246900000000001, 'prompt_tokens': 193056, 'completion_tokens': 17294, 'total_tokens': 210350}
# {'task_id': 'HumanEval_122_add_elements', 'task_time': 1379.4307520389557, 'total_inference_time': 644.1229093074799, 'cost': 0.12070200000000005, 'prompt_tokens': 193635, 'completion_tokens': 15923, 'total_tokens': 209558}
# {'task_id': 'HumanEval_46_fib4', 'task_time': 1444.5916030406952, 'total_inference_time': 683.9649608135223, 'cost': 0.12889099999999995, 'prompt_tokens': 193714, 'completion_tokens': 21356, 'total_tokens': 215070}
# {'task_id': 'HumanEval_104_unique_digits', 'task_time': 14.77505898475647, 'total_inference_time': 9.03320574760437, 'cost': 0.000356, 'prompt_tokens': 481, 'completion_tokens': 77, 'total_tokens': 558}
# {'task_id': 'HumanEval_117_select_words', 'task_time': 16.7240207195282, 'total_inference_time': 8.548848628997803, 'cost': 0.000705, 'prompt_tokens': 651, 'completion_tokens': 253, 'total_tokens': 904}
# {'task_id': 'HumanEval_72_will_it_fly', 'task_time': 17.22886085510254, 'total_inference_time': 8.676647663116455, 'cost': 0.000735, 'prompt_tokens': 741, 'completion_tokens': 243, 'total_tokens': 984}
# {'task_id': 'HumanEval_55_fib', 'task_time': 16.879383325576782, 'total_inference_time': 11.466815710067749, 'cost': 0.000408, 'prompt_tokens': 363, 'completion_tokens': 151, 'total_tokens': 514}
# {'task_id': 'HumanEval_153_Strongest_Extension', 'task_time': 119.96904754638672, 'total_inference_time': 59.82779002189636, 'cost': 0.0081515, 'prompt_tokens': 9493, 'completion_tokens': 2270, 'total_tokens': 11763}
# {'task_id': 'HumanEval_119_match_parens', 'task_time': 1496.2794377803802, 'total_inference_time': 687.3051564693451, 'cost': 0.12755200000000003, 'prompt_tokens': 197951, 'completion_tokens': 19051, 'total_tokens': 217002}
# {'task_id': 'HumanEval_90_next_smallest', 'task_time': 137.8710594177246, 'total_inference_time': 65.2819504737854, 'cost': 0.010181999999999998, 'prompt_tokens': 15513, 'completion_tokens': 1617, 'total_tokens': 17130}
# {'task_id': 'HumanEval_92_any_int', 'task_time': 23.600642204284668, 'total_inference_time': 13.433769464492798, 'cost': 0.000608, 'prompt_tokens': 541, 'completion_tokens': 225, 'total_tokens': 766}
# {'task_id': 'HumanEval_2_truncate_number', 'task_time': 149.5465362071991, 'total_inference_time': 73.92237401008606, 'cost': 0.0087385, 'prompt_tokens': 14663, 'completion_tokens': 938, 'total_tokens': 15601}
# {'task_id': 'HumanEval_42_incr_list', 'task_time': 106.18827962875366, 'total_inference_time': 45.738808393478394, 'cost': 0.004657, 'prompt_tokens': 7538, 'completion_tokens': 592, 'total_tokens': 8130}
# {'task_id': 'HumanEval_150_x_or_y', 'task_time': 22.385422945022583, 'total_inference_time': 12.541556358337402, 'cost': 0.0008365000000000001, 'prompt_tokens': 443, 'completion_tokens': 410, 'total_tokens': 853}
# {'task_id': 'HumanEval_49_modp', 'task_time': 16.34365701675415, 'total_inference_time': 10.261325359344482, 'cost': 0.00036799999999999995, 'prompt_tokens': 469, 'completion_tokens': 89, 'total_tokens': 558}
# {'task_id': 'HumanEval_155_even_odd_count', 'task_time': 20.653206825256348, 'total_inference_time': 11.276241302490234, 'cost': 0.0005155, 'prompt_tokens': 413, 'completion_tokens': 206, 'total_tokens': 619}
# {'task_id': 'HumanEval_80_is_happy', 'task_time': 17.589664697647095, 'total_inference_time': 8.89076280593872, 'cost': 0.0005355, 'prompt_tokens': 525, 'completion_tokens': 182, 'total_tokens': 707}
# {'task_id': 'HumanEval_59_largest_prime_factor', 'task_time': 16.993674516677856, 'total_inference_time': 9.59639573097229, 'cost': 0.0005525, 'prompt_tokens': 385, 'completion_tokens': 240, 'total_tokens': 625}
# {'task_id': 'HumanEval_66_digitSum', 'task_time': 20.18323826789856, 'total_inference_time': 12.308252573013306, 'cost': 0.00048499999999999997, 'prompt_tokens': 499, 'completion_tokens': 157, 'total_tokens': 656}
# {'task_id': 'HumanEval_21_rescale_to_unit', 'task_time': 123.2780864238739, 'total_inference_time': 60.660396575927734, 'cost': 0.0093895, 'prompt_tokens': 13646, 'completion_tokens': 1711, 'total_tokens': 15357}
# {'task_id': 'HumanEval_121_solution', 'task_time': 1560.194373369217, 'total_inference_time': 656.254875421524, 'cost': 0.115168, 'prompt_tokens': 189749, 'completion_tokens': 13529, 'total_tokens': 203278}
# {'task_id': 'HumanEval_68_pluck', 'task_time': 117.48038840293884, 'total_inference_time': 64.21298170089722, 'cost': 0.012959000000000002, 'prompt_tokens': 17161, 'completion_tokens': 2919, 'total_tokens': 20080}
# {'task_id': 'HumanEval_147_get_max_triples', 'task_time': 1645.8208575248718, 'total_inference_time': 776.4726693630219, 'cost': 0.13707049999999996, 'prompt_tokens': 201457, 'completion_tokens': 24228, 'total_tokens': 225685}
# {'task_id': 'HumanEval_110_exchange', 'task_time': 1593.6034662723541, 'total_inference_time': 757.0889177322388, 'cost': 0.14124, 'prompt_tokens': 217035, 'completion_tokens': 21815, 'total_tokens': 238850}
# {'task_id': 'HumanEval_47_median', 'task_time': 20.16288733482361, 'total_inference_time': 11.327160835266113, 'cost': 0.000704, 'prompt_tokens': 421, 'completion_tokens': 329, 'total_tokens': 750}
# {'task_id': 'HumanEval_82_prime_length', 'task_time': 1379.6791758537292, 'total_inference_time': 616.1004810333252, 'cost': 0.11383250000000003, 'prompt_tokens': 181207, 'completion_tokens': 15486, 'total_tokens': 196693}
# {'task_id': 'HumanEval_73_smallest_change', 'task_time': 1455.0007317066193, 'total_inference_time': 673.4179961681366, 'cost': 0.13519249999999997, 'prompt_tokens': 207388, 'completion_tokens': 20999, 'total_tokens': 228387}
# {'task_id': 'HumanEval_133_sum_squares', 'task_time': 221.43567180633545, 'total_inference_time': 102.30892753601074, 'cost': 0.021141, 'prompt_tokens': 32931, 'completion_tokens': 3117, 'total_tokens': 36048}
# {'task_id': 'HumanEval_141_file_name_check', 'task_time': 1499.0584750175476, 'total_inference_time': 701.1345961093903, 'cost': 0.1336534999999999, 'prompt_tokens': 206056, 'completion_tokens': 20417, 'total_tokens': 226473}
# {'task_id': 'HumanEval_40_triples_sum_to_zero', 'task_time': 21.1457839012146, 'total_inference_time': 11.83902359008789, 'cost': 0.0007444999999999999, 'prompt_tokens': 589, 'completion_tokens': 300, 'total_tokens': 889}
# {'task_id': 'HumanEval_127_intersection', 'task_time': 1491.6559534072876, 'total_inference_time': 711.1688339710236, 'cost': 0.12790199999999996, 'prompt_tokens': 196857, 'completion_tokens': 19649, 'total_tokens': 216506}
# {'task_id': 'HumanEval_1_separate_paren_groups', 'task_time': 17.531064987182617, 'total_inference_time': 12.257049322128296, 'cost': 0.0007034999999999999, 'prompt_tokens': 483, 'completion_tokens': 308, 'total_tokens': 791}
# {'task_id': 'HumanEval_152_compare', 'task_time': 88.06237030029297, 'total_inference_time': 38.838608264923096, 'cost': 0.007169499999999999, 'prompt_tokens': 10277, 'completion_tokens': 1354, 'total_tokens': 11631}
# {'task_id': 'HumanEval_134_check_if_last_char_is_a_letter', 'task_time': 21.926947116851807, 'total_inference_time': 14.805037021636963, 'cost': 0.001902, 'prompt_tokens': 537, 'completion_tokens': 1089, 'total_tokens': 1626}
# {'task_id': 'HumanEval_124_valid_date', 'task_time': 232.4762463569641, 'total_inference_time': 135.06816339492798, 'cost': 0.020202, 'prompt_tokens': 25779, 'completion_tokens': 4875, 'total_tokens': 30654}
# {'task_id': 'HumanEval_108_count_nums', 'task_time': 527.2522633075714, 'total_inference_time': 234.43810629844666, 'cost': 0.022653500000000007, 'prompt_tokens': 30061, 'completion_tokens': 5082, 'total_tokens': 35143}
# {'task_id': 'HumanEval_86_anti_shuffle', 'task_time': 1176.728491306305, 'total_inference_time': 554.593672990799, 'cost': 0.11465149999999998, 'prompt_tokens': 180472, 'completion_tokens': 16277, 'total_tokens': 196749}
# {'task_id': 'HumanEval_48_is_palindrome', 'task_time': 120.78754329681396, 'total_inference_time': 50.47842001914978, 'cost': 0.0039689999999999994, 'prompt_tokens': 6555, 'completion_tokens': 461, 'total_tokens': 7016}
# {'task_id': 'HumanEval_118_get_closest_vowel', 'task_time': 160.99145078659058, 'total_inference_time': 84.35583019256592, 'cost': 0.0192075, 'prompt_tokens': 29040, 'completion_tokens': 3125, 'total_tokens': 32165}
# {'task_id': 'HumanEval_31_is_prime', 'task_time': 19.001028537750244, 'total_inference_time': 11.091967821121216, 'cost': 0.000409, 'prompt_tokens': 461, 'completion_tokens': 119, 'total_tokens': 580}
# {'task_id': 'HumanEval_144_simplify', 'task_time': 20.618430852890015, 'total_inference_time': 13.122736692428589, 'cost': 0.0006815, 'prompt_tokens': 583, 'completion_tokens': 260, 'total_tokens': 843}
# {'task_id': 'HumanEval_78_hex_key', 'task_time': 18.33656334877014, 'total_inference_time': 9.132757902145386, 'cost': 0.000594, 'prompt_tokens': 831, 'completion_tokens': 119, 'total_tokens': 950}
# {'task_id': 'HumanEval_143_words_in_sentence', 'task_time': 1468.6749277114868, 'total_inference_time': 715.6265015602112, 'cost': 0.1234155, 'prompt_tokens': 187686, 'completion_tokens': 19715, 'total_tokens': 207401}
# {'task_id': 'HumanEval_111_histogram', 'task_time': 94.1869740486145, 'total_inference_time': 47.12111210823059, 'cost': 0.0064435, 'prompt_tokens': 7652, 'completion_tokens': 1745, 'total_tokens': 9397}
# {'task_id': 'HumanEval_87_get_row', 'task_time': 1418.21954703331, 'total_inference_time': 683.9906907081604, 'cost': 0.14269799999999996, 'prompt_tokens': 224061, 'completion_tokens': 20445, 'total_tokens': 244506}
# {'task_id': 'HumanEval_123_get_odd_collatz', 'task_time': 1630.3823471069336, 'total_inference_time': 737.2247643470764, 'cost': 0.13032450000000007, 'prompt_tokens': 200289, 'completion_tokens': 20120, 'total_tokens': 220409}
# {'task_id': 'HumanEval_135_can_arrange', 'task_time': 1611.3229970932007, 'total_inference_time': 714.0888669490814, 'cost': 0.12852499999999997, 'prompt_tokens': 206305, 'completion_tokens': 16915, 'total_tokens': 223220}
# {'task_id': 'HumanEval_19_sort_numbers', 'task_time': 19.88353991508484, 'total_inference_time': 10.452329158782959, 'cost': 0.0007395, 'prompt_tokens': 453, 'completion_tokens': 342, 'total_tokens': 795}
# {'task_id': 'HumanEval_65_circular_shift', 'task_time': 176.47176694869995, 'total_inference_time': 83.98639464378357, 'cost': 0.012287500000000002, 'prompt_tokens': 16406, 'completion_tokens': 2723, 'total_tokens': 19129}
# {'task_id': 'HumanEval_142_sum_squares', 'task_time': 1640.0123465061188, 'total_inference_time': 735.0707666873932, 'cost': 0.13101799999999997, 'prompt_tokens': 207433, 'completion_tokens': 18201, 'total_tokens': 225634}
# {'task_id': 'HumanEval_94_skjkasdkd', 'task_time': 129.35333824157715, 'total_inference_time': 62.33505439758301, 'cost': 0.008848, 'prompt_tokens': 11615, 'completion_tokens': 2027, 'total_tokens': 13642}
# {'task_id': 'HumanEval_8_sum_product', 'task_time': 1272.8433628082275, 'total_inference_time': 587.2329623699188, 'cost': 0.113342, 'prompt_tokens': 179869, 'completion_tokens': 15605, 'total_tokens': 195474}
# {'task_id': 'HumanEval_102_choose_num', 'task_time': 460.9195861816406, 'total_inference_time': 161.5088129043579, 'cost': 0.015292999999999998, 'prompt_tokens': 22552, 'completion_tokens': 2678, 'total_tokens': 25230}
# {'task_id': 'HumanEval_136_largest_smallest_integers', 'task_time': 2429.2815103530884, 'total_inference_time': 1085.509465932846, 'cost': 0.13389099999999995, 'prompt_tokens': 212087, 'completion_tokens': 18565, 'total_tokens': 230652}
# {'task_id': 'HumanEval_16_count_distinct_characters', 'task_time': 25.736998558044434, 'total_inference_time': 15.252426385879517, 'cost': 0.00041249999999999994, 'prompt_tokens': 393, 'completion_tokens': 144, 'total_tokens': 537}
# {'task_id': 'HumanEval_100_make_a_pile', 'task_time': 53.48016881942749, 'total_inference_time': 53.377917766571045, 'cost': 0.032277499999999994, 'prompt_tokens': 50392, 'completion_tokens': 4721, 'total_tokens': 55113}
# {'task_id': 'HumanEval_128_prod_signs', 'task_time': 199.5961377620697, 'total_inference_time': 199.2856683731079, 'cost': 0.12397450000000004, 'prompt_tokens': 198389, 'completion_tokens': 16520, 'total_tokens': 214909}
# {'task_id': 'HumanEval_114_minSubArraySum', 'task_time': 4.07072639465332, 'total_inference_time': 4.067896127700806, 'cost': 0.000817, 'prompt_tokens': 455, 'completion_tokens': 393, 'total_tokens': 848}
# {'task_id': 'HumanEval_15_string_sequence', 'task_time': 1.148439884185791, 'total_inference_time': 1.146265983581543, 'cost': 0.0003595, 'prompt_tokens': 389, 'completion_tokens': 110, 'total_tokens': 499}
# {'task_id': 'HumanEval_154_cycpattern_check', 'task_time': 1.3192408084869385, 'total_inference_time': 1.3161752223968506, 'cost': 0.00047699999999999994, 'prompt_tokens': 549, 'completion_tokens': 135, 'total_tokens': 684}
# {'task_id': 'HumanEval_57_monotonic', 'task_time': 2.6457581520080566, 'total_inference_time': 2.6421263217926025, 'cost': 0.000527, 'prompt_tokens': 445, 'completion_tokens': 203, 'total_tokens': 648}
# {'task_id': 'HumanEval_12_longest', 'task_time': 185.4178605079651, 'total_inference_time': 185.07012820243835, 'cost': 0.1261155, 'prompt_tokens': 200559, 'completion_tokens': 17224, 'total_tokens': 217783}
# {'task_id': 'HumanEval_52_below_threshold', 'task_time': 130.5286202430725, 'total_inference_time': 130.18040823936462, 'cost': 0.10581999999999997, 'prompt_tokens': 174200, 'completion_tokens': 12480, 'total_tokens': 186680}
# {'task_id': 'HumanEval_75_is_multiply_prime', 'task_time': 1606.9691293239594, 'total_inference_time': 587.4389386177063, 'cost': 0.06464799999999998, 'prompt_tokens': 97535, 'completion_tokens': 10587, 'total_tokens': 108122}
# {'task_id': 'HumanEval_30_get_positive', 'task_time': 285.87870502471924, 'total_inference_time': 128.88213467597961, 'cost': 0.006085999999999999, 'prompt_tokens': 10129, 'completion_tokens': 681, 'total_tokens': 10810}
# {'task_id': 'HumanEval_33_sort_third', 'task_time': 3128.4002203941345, 'total_inference_time': 1558.2368834018707, 'cost': 0.1459585, 'prompt_tokens': 228911, 'completion_tokens': 21002, 'total_tokens': 249913}
# {'task_id': 'HumanEval_6_parse_nested_parens', 'task_time': 893.6799194812775, 'total_inference_time': 411.8790509700775, 'cost': 0.0338995, 'prompt_tokens': 54278, 'completion_tokens': 4507, 'total_tokens': 58785}
# {'task_id': 'HumanEval_45_triangle_area', 'task_time': 33.01521682739258, 'total_inference_time': 14.289188146591187, 'cost': 0.00043900000000000005, 'prompt_tokens': 359, 'completion_tokens': 173, 'total_tokens': 532}
# {'task_id': 'HumanEval_97_multiply', 'task_time': 2419.47123837471, 'total_inference_time': 1110.7936570644379, 'cost': 0.075751, 'prompt_tokens': 125141, 'completion_tokens': 8787, 'total_tokens': 133928}
# {'task_id': 'HumanEval_4_mean_absolute_deviation', 'task_time': 2542.8542544841766, 'total_inference_time': 1324.218361377716, 'cost': 0.11783699999999991, 'prompt_tokens': 189075, 'completion_tokens': 15533, 'total_tokens': 204608}
# {'task_id': 'HumanEval_58_common', 'task_time': 32.69374489784241, 'total_inference_time': 19.469146251678467, 'cost': 0.00079, 'prompt_tokens': 503, 'completion_tokens': 359, 'total_tokens': 862}
# {'task_id': 'HumanEval_156_int_to_mini_roman', 'task_time': 38.289660930633545, 'total_inference_time': 17.77043867111206, 'cost': 0.0007545000000000001, 'prompt_tokens': 465, 'completion_tokens': 348, 'total_tokens': 813}
# {'task_id': 'HumanEval_67_fruit_distribution', 'task_time': 45.150625467300415, 'total_inference_time': 25.841402769088745, 'cost': 0.0005074999999999999, 'prompt_tokens': 631, 'completion_tokens': 128, 'total_tokens': 759}
# {'task_id': 'HumanEval_112_reverse_delete', 'task_time': 4162.473791837692, 'total_inference_time': 2095.779948949814, 'cost': 0.12068599999999997, 'prompt_tokens': 189790, 'completion_tokens': 17194, 'total_tokens': 206984}
# {'task_id': 'HumanEval_13_greatest_common_divisor', 'task_time': 39.42939472198486, 'total_inference_time': 24.186058282852173, 'cost': 0.000483, 'prompt_tokens': 393, 'completion_tokens': 191, 'total_tokens': 584}
# {'task_id': 'HumanEval_125_split_words', 'task_time': 5122.468677282333, 'total_inference_time': 2314.7914600372314, 'cost': 0.14019049999999997, 'prompt_tokens': 217003, 'completion_tokens': 21126, 'total_tokens': 238129}
# {'task_id': 'HumanEval_116_sort_array', 'task_time': 4992.159340620041, 'total_inference_time': 2474.907593011856, 'cost': 0.14939450000000004, 'prompt_tokens': 231118, 'completion_tokens': 22557, 'total_tokens': 253675}
# {'task_id': 'HumanEval_28_concatenate', 'task_time': 60.64871168136597, 'total_inference_time': 37.869784116744995, 'cost': 0.000329, 'prompt_tokens': 367, 'completion_tokens': 97, 'total_tokens': 464}
# {'task_id': 'HumanEval_149_sorted_list_sum', 'task_time': 55.52969574928284, 'total_inference_time': 28.762439489364624, 'cost': 0.0007559999999999999, 'prompt_tokens': 651, 'completion_tokens': 287, 'total_tokens': 938}
# {'task_id': 'HumanEval_7_filter_by_substring', 'task_time': 173.56643414497375, 'total_inference_time': 173.1468632221222, 'cost': 0.12768949999999998, 'prompt_tokens': 204526, 'completion_tokens': 16951, 'total_tokens': 221477}
# {'task_id': 'HumanEval_99_closest_integer', 'task_time': 47.95314908027649, 'total_inference_time': 47.886605978012085, 'cost': 0.030395499999999995, 'prompt_tokens': 46604, 'completion_tokens': 4729, 'total_tokens': 51333}
# {'task_id': 'HumanEval_64_vowels_count', 'task_time': 200.02583169937134, 'total_inference_time': 199.7208650112152, 'cost': 0.11563749999999999, 'prompt_tokens': 173102, 'completion_tokens': 19391, 'total_tokens': 192493}
# {'task_id': 'HumanEval_158_find_max', 'task_time': 4.975336313247681, 'total_inference_time': 4.971534967422485, 'cost': 0.0006925000000000001, 'prompt_tokens': 521, 'completion_tokens': 288, 'total_tokens': 809}
# {'task_id': 'HumanEval_162_string_to_md5', 'task_time': 174.76674008369446, 'total_inference_time': 174.4923357963562, 'cost': 0.11810699999999995, 'prompt_tokens': 192726, 'completion_tokens': 14496, 'total_tokens': 207222}
# {'task_id': 'HumanEval_44_change_base', 'task_time': 35.41509222984314, 'total_inference_time': 35.30239176750183, 'cost': 0.027862500000000002, 'prompt_tokens': 44814, 'completion_tokens': 3637, 'total_tokens': 48451}
# {'task_id': 'HumanEval_157_right_angle_triangle', 'task_time': 2.964421510696411, 'total_inference_time': 2.9614264965057373, 'cost': 0.000589, 'prompt_tokens': 491, 'completion_tokens': 229, 'total_tokens': 720}
# {'task_id': 'HumanEval_81_numerical_letter_grade', 'task_time': 229.67710900306702, 'total_inference_time': 229.08043956756592, 'cost': 0.167274, 'prompt_tokens': 263229, 'completion_tokens': 23773, 'total_tokens': 287002}
# {'task_id': 'HumanEval_5_intersperse', 'task_time': 11.431200742721558, 'total_inference_time': 11.405540704727173, 'cost': 0.0058425, 'prompt_tokens': 8265, 'completion_tokens': 1140, 'total_tokens': 9405}
# {'task_id': 'HumanEval_146_specialFilter', 'task_time': 196.74774146080017, 'total_inference_time': 196.36157703399658, 'cost': 0.11857949999999998, 'prompt_tokens': 185106, 'completion_tokens': 17351, 'total_tokens': 202457}
# {'task_id': 'HumanEval_60_sum_to_n', 'task_time': 1.5166325569152832, 'total_inference_time': 1.5142748355865479, 'cost': 0.0003495, 'prompt_tokens': 447, 'completion_tokens': 84, 'total_tokens': 531}
# {'task_id': 'HumanEval_26_remove_duplicates', 'task_time': 177.4631862640381, 'total_inference_time': 177.11140394210815, 'cost': 0.12183449999999998, 'prompt_tokens': 193575, 'completion_tokens': 16698, 'total_tokens': 210273}
# {'task_id': 'HumanEval_163_generate_integers', 'task_time': 174.1926610469818, 'total_inference_time': 173.68690180778503, 'cost': 0.13385200000000003, 'prompt_tokens': 225332, 'completion_tokens': 14124, 'total_tokens': 239456}
# {'task_id': 'HumanEval_9_rolling_max', 'task_time': 5.11775803565979, 'total_inference_time': 5.114719390869141, 'cost': 0.0006265, 'prompt_tokens': 449, 'completion_tokens': 268, 'total_tokens': 717}
# {'task_id': 'HumanEval_3_below_zero', 'task_time': 144.7565634250641, 'total_inference_time': 144.23837113380432, 'cost': 0.10939600000000005, 'prompt_tokens': 177800, 'completion_tokens': 13664, 'total_tokens': 191464}
# {'task_id': 'HumanEval_69_search', 'task_time': 147.06456470489502, 'total_inference_time': 146.65908312797546, 'cost': 0.11642749999999998, 'prompt_tokens': 188563, 'completion_tokens': 14764, 'total_tokens': 203327}
# {'task_id': 'HumanEval_61_correct_bracketing', 'task_time': 8.142516374588013, 'total_inference_time': 8.139544248580933, 'cost': 0.000639, 'prompt_tokens': 441, 'completion_tokens': 279, 'total_tokens': 720}
# {'task_id': 'HumanEval_37_sort_even', 'task_time': 203.95962977409363, 'total_inference_time': 203.41767144203186, 'cost': 0.126907, 'prompt_tokens': 200354, 'completion_tokens': 17820, 'total_tokens': 218174}
# {'task_id': 'HumanEval_54_same_chars', 'task_time': 1.1339976787567139, 'total_inference_time': 1.1316196918487549, 'cost': 0.00046, 'prompt_tokens': 539, 'completion_tokens': 127, 'total_tokens': 666}
# {'task_id': 'HumanEval_56_correct_bracketing', 'task_time': 146.3147804737091, 'total_inference_time': 145.8356966972351, 'cost': 0.1079825, 'prompt_tokens': 173425, 'completion_tokens': 14180, 'total_tokens': 187605}
# {'task_id': 'HumanEval/32', 'task_time': 220.19975876808167, 'total_inference_time': 219.4130985736847, 'cost': 0.12991499999999995, 'prompt_tokens': 193878, 'completion_tokens': 21984, 'total_tokens': 215862}
# {'task_id': 'HumanEval/50', 'task_time': 29.391438961029053, 'total_inference_time': 29.27826690673828, 'cost': 0.020367499999999997, 'prompt_tokens': 33361, 'completion_tokens': 2458, 'total_tokens': 35819}
# {'task_id': 'HumanEval/38', 'task_time': 220.098876953125, 'total_inference_time': 219.27135920524597, 'cost': 0.1270735, 'prompt_tokens': 197243, 'completion_tokens': 18968, 'total_tokens': 216211}

# %%
import json
import os
import pandas as pd
import statistics
from typing import Dict, List, Tuple

def analyze_logs_from_roots(root_dirs: List[str]) -> pd.DataFrame:
    """Analyzes log files from multiple root directories and stores results in a DataFrame.

    Args:
        root_dirs: A list of root directory paths.

    Returns:
        A Pandas DataFrame containing aggregate statistics for each log file.
    """

    all_aggregate_stats = []
    for root_dir in root_dirs:
        for dirpath, dirnames, filenames in os.walk(root_dir):
            for filename in filenames:
                if filename.endswith(".log"):
                    log_path = os.path.join(dirpath, filename)
                    aggregate_stats, _ = analyze_log(log_path)
                    # Add a column to specify the location of the log file
                    aggregate_stats['location'] = dirpath
                    all_aggregate_stats.append(aggregate_stats)

    df = pd.DataFrame(all_aggregate_stats)

    # Split 'location' column into separate columns for each path level
    location_levels = df['location'].str.split('/', expand=True)
    max_levels = location_levels.shape[1]  # Get the maximum number of path levels
    # Rename columns to "level_1", "level_2", etc.
    location_levels.columns = [f"level_{i+1}" for i in range(max_levels)]

    # only keep the last levels
    location_levels = location_levels.iloc[:, -4:]

    # rename the columns
    location_levels.columns = ['strategy', 'dataset', 'model', 'run']

    # Concatenate the split levels with the original DataFrame
    df = pd.concat([df, location_levels], axis=1)
    df = df.drop('location', axis=1) 
    # If model is codellama replace cell value with 'Escalation strategy'
    df['model'] = df['model'].replace('CodeLlama-34b-Instruct-hf', 'CL > GPT3.5 > GPT4')

    # add total_inference_time and total_cost of simple to ldb for same run and model
    for index, row in df.iterrows():
        if row['strategy'] == 'simple':
            simple_inference_time = row['total_inference_time']
            simple_cost = row['total_cost']
            simple_model = row['model']
            simple_dataset = row['dataset']
            simple_run = row['run']
            for index2, row2 in df.iterrows():
                if row2['strategy'] == 'ldb' and simple_model == row2['model'].split('+')[1] and row2['run'] == simple_run and row2['dataset'] == simple_dataset:
                    print(row['strategy'], simple_model, simple_run)
                    print(row2['strategy'], row2['model'], row2['run'])
                    print(row2['total_cost'], simple_cost)
                    df.at[index2, 'total_inference_time'] += simple_inference_time
                    df.at[index2, 'total_cost'] += simple_cost
                    print(df.at[index2, 'total_cost'])

                    

    # add total_inference_time and total_cost of reflexion to ldb for same run and model, if ldb modelname includes "reflexion"
    for index, row in df.iterrows():
        if row['strategy'] == 'reflexion':
            simple_inference_time = row['total_inference_time']
            simple_cost = row['total_cost']
            simple_model = row['model']
            simple_dataset = row['dataset']
            simple_run = row['run']
            for index2, row2 in df.iterrows():
                if "gpt-4" in simple_model:
                    if row2['strategy'] == 'ldb' and simple_model == row2['model'].split('+')[0] and row2['run'] == simple_run and row2['dataset'] == simple_dataset and 'reflexion' in row2['model']:
                        print(row2['strategy'], row2['model'], row2['run'])
                        print(row2['total_cost'], simple_cost)
                        df.at[index2, 'total_inference_time'] += simple_inference_time
                        df.at[index2, 'total_cost'] += simple_cost
                        print(df.at[index2, 'total_cost'])
                    elif row2['strategy'] == 'ldb' and "gpt-4-0613" == simple_model and "0613" in row2['model'] and row2['run'] == simple_run and row2['dataset'] == simple_dataset and 'reflexion' in row2['model']:
                        print(row2['strategy'], row2['model'], row2['run'])
                        print(row2['total_cost'], simple_cost)
                        df.at[index2, 'total_inference_time'] += simple_inference_time
                        df.at[index2, 'total_cost'] += simple_cost
                        print(df.at[index2, 'total_cost'])
                    elif row2['strategy'] == 'ldb' and "gpt-4-turbo-2024-04-09" == simple_model and "0125" in row2['model'] and row2['run'] == simple_run and row2['dataset'] == simple_dataset and 'reflexion' in row2['model']:
                        print(row2['strategy'], row2['model'], row2['run'])
                        print(row2['total_cost'], simple_cost)
                        df.at[index2, 'total_inference_time'] += simple_inference_time
                        df.at[index2, 'total_cost'] += simple_cost
                        print(df.at[index2, 'total_cost'])
                else:
                    pass
                    
    return df 

# Example usage:
if __name__ == '__main__':
    root_directories = ['LLMDebugger/output_data/simple', 
                        'LLMDebugger/output_data/ldb', 
                        'LLMDebugger/output_data/simple_boosting',
                        "reflexion/output_data",
                        "LLMDebugger/output_data/simple_incr_temp",
                        "LLMDebugger/output_data/simple_repeat",
                        "LanguageAgentTreeSearch/output_data/lats"
                        ]  # Replace with your actual root directories
    data = analyze_logs_from_roots(root_directories)
    # store the dataframe
    data.to_csv('LLMDebugger/output_data/humaneval_results.csv', index=False)
# Out:
# simple gpt-3.5-turbo-1106 run1
# ldb gpt-3.5-turbo-1106+gpt-3.5-turbo-1106 run1
# 0.5690035000000003 0.04815250000000001
# 0.6171560000000004
# simple gpt-3.5-turbo-1106 run2
# ldb gpt-3.5-turbo-1106+gpt-3.5-turbo-1106 run2
# 0.5843944999999996 0.0489535
# 0.6333479999999996
# simple gpt-3.5-turbo-1106 run3
# ldb gpt-3.5-turbo-1106+gpt-3.5-turbo-1106 run3
# 0.6137410000000003 0.048277000000000014
# 0.6620180000000003
# simple gpt-3.5-turbo-1106 run4
# ldb gpt-3.5-turbo-1106+gpt-3.5-turbo-1106 run4
# 0.5529450000000004 0.049299999999999976
# 0.6022450000000004
# simple gpt-3.5-turbo-1106 run5
# ldb gpt-3.5-turbo-1106+gpt-3.5-turbo-1106 run5
# 0.5722244999999997 0.048714999999999994
# 0.6209394999999996
# simple gpt-4-0613 run1
# ldb gpt-4-0613+gpt-4-0613 run1
# 5.3504100000000046 2.9221800000000013
# 8.272590000000006
# simple gpt-4-0613 run1
# ldb gpt-3.5-turbo-0613+gpt-4-0613 run1
# 0.220767 2.9221800000000013
# 3.1429470000000013
# simple gpt-4-0613 run2
# ldb gpt-4-0613+gpt-4-0613 run2
# 7.020659999999998 2.9284199999999996
# 9.949079999999997
# simple gpt-4-0613 run2
# ldb gpt-3.5-turbo-0613+gpt-4-0613 run2
# 0.3035819999999999 2.9284199999999996
# 3.2320019999999996
# simple gpt-4-0613 run3
# ldb gpt-4-0613+gpt-4-0613 run3
# 5.768159999999999 2.9309400000000005
# 8.6991
# simple gpt-4-0613 run3
# ldb gpt-3.5-turbo-0613+gpt-4-0613 run3
# 0.27826850000000025 2.9309400000000005
# 3.209208500000001
# simple gpt-4-0613 run4
# ldb gpt-4-0613+gpt-4-0613 run4
# 6.417780000000001 2.94594
# 9.36372
# simple gpt-4-0613 run4
# ldb gpt-3.5-turbo-0613+gpt-4-0613 run4
# 0.3133755000000001 2.94594
# 3.2593155
# simple gpt-4-0613 run5
# ldb gpt-4-0613+gpt-4-0613 run5
# 7.311630000000003 2.9515800000000008
# 10.263210000000004
# simple gpt-4-0613 run5
# ldb gpt-3.5-turbo-0613+gpt-4-0613 run5
# 0.21705449999999993 2.9515800000000008
# 3.1686345000000005
# simple gpt-3.5-turbo-0613 run1
# ldb gpt-3.5-turbo-0613+gpt-3.5-turbo-0613 run1
# 0.6322869999999997 0.04114000000000001
# 0.6734269999999998
# simple gpt-3.5-turbo-0613 run2
# ldb gpt-3.5-turbo-0613+gpt-3.5-turbo-0613 run2
# 0.608223 0.041852499999999994
# 0.6500754999999999
# simple gpt-3.5-turbo-0613 run3
# ldb gpt-3.5-turbo-0613+gpt-3.5-turbo-0613 run3
# 0.6564470000000006 0.0416755
# 0.6981225000000005
# simple gpt-3.5-turbo-0613 run4
# ldb gpt-3.5-turbo-0613+gpt-3.5-turbo-0613 run4
# 0.6115364999999996 0.04205949999999999
# 0.6535959999999996
# simple gpt-3.5-turbo-0613 run5
# ldb gpt-3.5-turbo-0613+gpt-3.5-turbo-0613 run5
# 0.6781240000000002 0.0419545
# 0.7200785000000002
# simple gpt-4-turbo-2024-04-09 run1
# ldb gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09 run1
# 5.008990000000002 1.9245200000000013
# 6.933510000000003
# simple gpt-4-turbo-2024-04-09 run1
# ldb gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09 run1
# 0.25254549999999976 1.9245200000000013
# 2.177065500000001
# simple gpt-4-turbo-2024-04-09 run2
# ldb gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09 run2
# 5.152839999999999 1.9250900000000004
# 7.07793
# simple gpt-4-turbo-2024-04-09 run2
# ldb gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09 run2
# 0.3289105000000003 1.9250900000000004
# 2.254000500000001
# simple gpt-4-turbo-2024-04-09 run3
# ldb gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09 run3
# 3.1596600000000006 1.9540100000000002
# 5.113670000000001
# simple gpt-4-turbo-2024-04-09 run3
# ldb gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09 run3
# 0.2209415000000001 1.9540100000000002
# 2.1749515
# simple gpt-4-turbo-2024-04-09 run4
# ldb gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09 run4
# 4.049660000000001 1.9326799999999997
# 5.982340000000001
# simple gpt-4-turbo-2024-04-09 run4
# ldb gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09 run4
# 0.20762750000000033 1.9326799999999997
# 2.1403075
# simple gpt-4-turbo-2024-04-09 run5
# ldb gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09 run5
# 4.755249999999998 1.9142600000000007
# 6.669509999999999
# simple gpt-4-turbo-2024-04-09 run5
# ldb gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09 run5
# 0.2823335000000001 1.9142600000000007
# 2.196593500000001
# simple gpt-3.5-turbo-0125 run1
# ldb gpt-3.5-turbo-0125+gpt-3.5-turbo-0125 run1
# 0.5052235 0.05519650000000002
# 0.56042
# simple gpt-3.5-turbo-0125 run2
# ldb gpt-3.5-turbo-0125+gpt-3.5-turbo-0125 run2
# 0.7178700000000001 0.055144000000000026
# 0.7730140000000001
# simple gpt-3.5-turbo-0125 run3
# ldb gpt-3.5-turbo-0125+gpt-3.5-turbo-0125 run3
# 0.5893144999999995 0.054908500000000034
# 0.6442229999999995
# simple gpt-3.5-turbo-0125 run4
# ldb gpt-3.5-turbo-0125+gpt-3.5-turbo-0125 run4
# 0.533438 0.054796000000000004
# 0.5882339999999999
# simple gpt-3.5-turbo-0125 run5
# ldb gpt-3.5-turbo-0125+gpt-3.5-turbo-0125 run5
# 0.5242034999999997 0.054224499999999995
# 0.5784279999999997
# simple gpt-4-1106-preview run1
# ldb gpt-4-1106-preview+gpt-4-1106-preview run1
# 2.762570000000001 1.8421999999999996
# 4.60477
# simple gpt-4-1106-preview run2
# ldb gpt-4-1106-preview+gpt-4-1106-preview run2
# 5.910499999999999 1.8566300000000002
# 7.767129999999999
# simple gpt-4-1106-preview run3
# ldb gpt-4-1106-preview+gpt-4-1106-preview run3
# 6.125940000000002 1.8530000000000004
# 7.978940000000002
# simple gpt-4-1106-preview run4
# ldb gpt-4-1106-preview+gpt-4-1106-preview run4
# 5.58788 1.869950000000001
# 7.457830000000001
# simple gpt-4-1106-preview run5
# ldb gpt-4-1106-preview+gpt-4-1106-preview run5
# 4.300520000000001 1.8520399999999995
# 6.15256
# ldb gpt-4-0613+reflexion run1
# 7.45491 8.691840000000001
# 16.14675
# ldb gpt-3.5-turbo-0613+reflexion run1
# 0.4349719999999995 8.691840000000001
# 9.126812000000001
# ldb gpt-4-0613+reflexion run2
# 12.497970000000006 8.299380000000005
# 20.79735000000001
# ldb gpt-3.5-turbo-0613+reflexion run2
# 0.47580350000000055 8.299380000000005
# 8.775183500000006
# ldb gpt-4-0613+reflexion run3
# 9.21866999999999 8.211120000000006
# 17.429789999999997
# ldb gpt-3.5-turbo-0613+reflexion run3
# 0.37776500000000013 8.211120000000006
# 8.588885000000007
# ldb gpt-4-0613+reflexion run4
# 10.972800000000007 8.262059999999998
# 19.234860000000005
# ldb gpt-3.5-turbo-0613+reflexion run4
# 0.3955920000000003 8.262059999999998
# 8.657651999999999
# ldb gpt-4-0613+reflexion run5
# 8.452920000000002 7.9815000000000005
# 16.434420000000003
# ldb gpt-3.5-turbo-0613+reflexion run5
# 0.4004025000000001 7.9815000000000005
# 8.3819025
# ldb gpt-4-turbo-2024-04-09+reflexion run1
# 3.18488 4.125810000000001
# 7.310690000000001
# ldb gpt-3.5-turbo-0125+reflexion run1
# 0.24410200000000004 4.125810000000001
# 4.369912000000001
# ldb gpt-4-turbo-2024-04-09+reflexion run2
# 2.4360000000000004 3.894630000000002
# 6.330630000000003
# ldb gpt-3.5-turbo-0125+reflexion run2
# 0.30474799999999974 3.894630000000002
# 4.199378000000002
# ldb gpt-4-turbo-2024-04-09+reflexion run3
# 2.42992 3.7624299999999993
# 6.192349999999999
# ldb gpt-3.5-turbo-0125+reflexion run3
# 0.21524949999999998 3.7624299999999993
# 3.9776794999999994
# ldb gpt-4-turbo-2024-04-09+reflexion run4
# 5.7721300000000015 3.862160000000003
# 9.634290000000004
# ldb gpt-3.5-turbo-0125+reflexion run4
# 0.32484599999999986 3.862160000000003
# 4.187006000000003
# ldb gpt-4-turbo-2024-04-09+reflexion run5
# 2.9997499999999997 3.843389999999999
# 6.843139999999998
# ldb gpt-3.5-turbo-0125+reflexion run5
# 0.3899234999999998 3.843389999999999
# 4.233313499999999

# %%
# filter lats with gpt4 0125
data = data[~((data['strategy'] == 'lats') & (data['model'] == 'gpt-4-turbo-0125'))].reset_index(drop=True)

# filter reflexion with gpt3.5
data = data[~((data['strategy'] == 'reflexion') & (data['model'] == 'gpt-3.5-turbo-0125'))].reset_index(drop=True)
data = data[~((data['strategy'] == 'reflexion') & (data['model'] == 'gpt-3.5-turbo-0613'))].reset_index(drop=True)

# Select agents for analysis
data_0409 = data[data['model'].isin(['gpt-3.5-turbo-0125', 
                                'gpt-4-turbo-2024-04-09', 
                                "l3_8b-gpt35-l3_70b-gpt4-0409",
                                "gpt-4-turbo-0409-5repeats-no-temp-incr",
                                "gpt-4-turbo-0409-5step", 
                                "gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09", 
                                'gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09',
                                'gpt-3.5-turbo-0125+gpt-3.5-turbo-0125',
                                "gpt-3.5-turbo-0125+reflexion", 
                                "gpt-4-turbo-2024-04-09+reflexion"])]

data_0613 = data[data['model'].isin(["gpt-3.5-turbo-0613",
                                     "gpt-4-0613", 
                                     "gpt-4-0613+gpt-4-0613",
                                     "gpt-3.5-turbo-0613+gpt-4-0613",
                                     "gpt-3.5-turbo-0613+gpt-3.5-turbo-0613",
                                     "gpt-3.5-turbo-0613+reflexion",
                                     "gpt-4-0613-5repeats-no-temp-incr",
                                     "gpt-3.5-turbo-0613-5repeats-no-temp-incr",
                                     "gpt-4-0613-5step", 
                                     "gpt-3.5-turbo-0613-5step", 
                                     "gpt-4-0613+reflexion", 
                                     "l3_8b-gpt-3.5-turbo-0613-l3_70b-gpt4-0613"])]


data_0409.to_csv("plot_data_0409.csv", index=False)
data_0613.to_csv("plot_data_0613.csv", index=False)

# %% [markdown]
# ## HumanEval

# %% [markdown]
# ## MinMax error bars

# %% [markdown]
# ### 0409

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

sns.set_style("whitegrid")
# Set the context for plotting 
sns.set_context("notebook", font_scale=1)  #

# Load the data
data = pd.read_csv('plot_data_0409.csv')

# Drop LATS
data = data[~((data['strategy'] == 'lats'))].reset_index(drop=True)


# Map the old strategy names to the new names
strategy_renames = {
    "ldb": "LDB",
    "lats": "LATS",
    "simple": "",
    "simple_boosting": "Escalation",
    "simple_incr_temp": "Warming",
    "reflexion": "Reflexion",
    "simple_repeat": "Retry"
}
data['strategy_renamed'] = data['strategy'].map(strategy_renames)

# Replace model names with more readable names
model_renames = {
    "gpt-3.5-turbo-0125": "GPT-3.5",
    "gpt-3.5-turbo-0125+gpt-3.5-turbo-0125": "GPT-3.5",
    "gpt-4-turbo-2024-04-09": "GPT-4",
    "gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09": "GPT-4",
    "gpt-4-turbo-0125": "GPT-4",
    "l3_8b-gpt35-l3_70b-gpt4": "gpt",
    "l3_8b-gpt35-l3_70b-gpt4-0409": "gpt",
    "gpt-4-turbo-0125": "GPT-4",
    "gpt-4-turbo-0409-5step": "GPT-4",
     "gpt-4-turbo-0409-1step": "GPT-4-1step",
     "gpt-4-turbo-0125-8repeats-no-temp-incr": "GPT-4",
     "gpt-4-turbo-2024-04-09+reflexion": "GPT-4+reflexion",
     "gpt-3.5-turbo-0125+reflexion": "GPT-3.5+reflexion",
     "gpt-4-turbo-0409-5repeats-no-temp-incr": "GPT-4",
     "gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09": "GPT-4, GPT-3.5",
    # "CL > GPT3.5 > GPT4": "CodeLlama"
}
data['model'] = data['model'].map(model_renames)

# Add model name to the strategy name
for i in range(data.shape[0]):
    if strategy_renames[data['strategy'][i]] == "":
        data.loc[i, 'strategy_renamed'] = data['model'][i]
    elif strategy_renames[data['strategy'][i]] == "Escalation":
        data.loc[i, 'strategy_renamed'] = "Escalation"
    else:
        data.loc[i, 'strategy_renamed'] = str(data['strategy_renamed'][i]) + " (" + str(data['model'][i]) + ")"
    #if strategy is ldb and model contains reflexion, then add reflexion to the strategy name
    if data['strategy'][i] == "ldb" and "reflexion" in data['model'][i]:
        data.loc[i, 'strategy_renamed'] = "LDB" + " (" + "Reflexion, " + str(data['model'][i]).replace("+reflexion", "") + ")"


blue = sns.color_palette("Dark2")[0]
orange = sns.color_palette("Dark2")[1]
green = sns.color_palette("Dark2")[2]

color_dict = {'GPT-4': blue,
 'GPT-3.5': blue,
 'LDB (GPT-4)': orange,
 'LDB (GPT-3.5)': orange,
 'Escalation': green,
 'Reflexion (GPT-4)': orange,
 "LATS (GPT-4, GPT-3.5)": orange,
 "Retry (GPT-4)": green,
 "Warming (GPT-4-1step)": blue,
 "LDB (Reflexion, GPT-4)": orange,
 "LDB (GPT-4, GPT-3.5)": orange,
 "LATS (GPT-4)": orange,
 "LATS (GPT-3.5)": orange,
 "LDB (Reflexion, GPT-3.5)": orange,
"Warming (GPT-4)": green,
'GPT-4': blue,
 'GPT-3.5': blue,
 'LDB (GPT-4)': orange,
 'LDB (GPT-3.5)': orange,
 'Escalation': green,
 'Reflexion (GPT-4)': orange,
 "LATS (GPT-3.5)": orange,
 "Retry (GPT-4)": green,
 "Warming (GPT-4-1step)": blue,
 "LDB (GPT-4, Reflexion)": orange,
 "LDB (GPT-3.5, GPT-4)": orange,
 "LATS (GPT-4)": orange,
 "LDB (GPT-3.5, Reflexion)": orange,
 "Reflexion (GPT-3.5)": orange,
 "Repeat (GPT-3.5)": green,
"Warming (GPT-4)": green}


# # Change colors of points based on strategy and model
# scatter_plot = sns.scatterplot(data=data, x='total_cost', y='accuracy', hue='strategy_renamed', palette=color_dict,
#                                 marker='o', s=200, legend=None)


# Group data by model and strategy, calculating mean and error bar ranges
grouped_data = data.groupby(['model', 'strategy_renamed']).agg(
    mean_accuracy=('accuracy', 'mean'),
    min_accuracy=('accuracy', 'min'),
    max_accuracy=('accuracy', 'max'),
    mean_cost=('total_cost', 'mean')
).reset_index()

# Calculate error bar values (max - mean and mean - min)
grouped_data['yerr_upper'] = grouped_data['max_accuracy'] - grouped_data['mean_accuracy']
grouped_data['yerr_lower'] = grouped_data['mean_accuracy'] - grouped_data['min_accuracy']


# Create the scatter plot with error bars
plt.figure(figsize=(12, 8))
scatter_plot = sns.scatterplot(
    data=grouped_data, 
    x='mean_cost', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None
)

# change color of the error bars
for i in range(len(grouped_data)):
    plt.errorbar(
        x=grouped_data['mean_cost'][i], 
        y=grouped_data['mean_accuracy'][i], 
        yerr=[[grouped_data['yerr_lower'][i]], [grouped_data['yerr_upper'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=color_dict[grouped_data['strategy_renamed'][i]],  # Use the same color as the scatter plot
        capsize=0,  # Add caps to the error bars
        elinewidth=3  # Adjust error bar line width
    )

# LEGEND
colors = [orange, green, blue]
labels = ['Complex agent', 'Baseline agent', 'Zero-shot model']
# Create empty scatter plots as legend handles
legend_handles = []
for color in colors:
    handle = plt.scatter([], [], c=color, marker='o')
    legend_handles.append(handle)
plt.legend(handles=legend_handles, labels=labels, loc="lower right")


# Setting the title and labels
# plt.title('Accuracy vs. Cost per Model and Agent on HumanEval', fontsize=16, pad=15)
plt.xlabel('Total Cost (USD, measured in April 2024)', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.grid(True)


# Setting the y-axis limits
plt.ylim(0.7, 1)
plt.xlim(0,)
# plt.xscale('log', base=10)

data = grouped_data
# Implementing label adjustments using simple lines
for i in range(data.shape[0]):
    annotation_text = data.strategy_renamed[i]
    x = data.mean_cost[i]
    y = data.mean_accuracy[i]
    if data.strategy_renamed[i] == "Escalation":
        xytext = (45, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-3.5":
        xytext = (50, -15)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-3.5)":
        xytext = (90, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4)":
        xytext = (-10, -15)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-3.5)":
        xytext = (160, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-4)":
        xytext = (30, -35)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4, GPT-3.5)":
        xytext = (0, 30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-3.5)":
        xytext = (110, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-4)":
        xytext = (-20, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4)":
        xytext = (90, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4-1step)":
        xytext = (10, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Retry (GPT-4)":
        xytext = (110,10)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-4":
        xytext = (40,-20)  # "Escalation" above the point
        ha = 'right'
    else:
        xytext = (30, -20)  # other strategies below the point to the right
        ha = 'right'

    scatter_plot.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))

plt.show()
# Out:
# /tmp/ipykernel_1777177/1231868328.py:149: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   handle = plt.scatter([], [], c=color, marker='o')

# %% [markdown]
# ### 0613

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

sns.set_style("whitegrid")
# Set the context for plotting 
sns.set_context("notebook", font_scale=1)  #

# Load the data
data = pd.read_csv('plot_data_0613.csv')

# Drop LATS
data = data[~((data['strategy'] == 'lats'))].reset_index(drop=True)


# Map the old strategy names to the new names
strategy_renames = {
    "ldb": "LDB",
    "lats": "LATS",
    "simple": "",
    "simple_boosting": "Escalation",
    "simple_incr_temp": "Warming",
    "reflexion": "Reflexion",
    "simple_repeat": "Retry"
}
data['strategy_renamed'] = data['strategy'].map(strategy_renames)

# Replace model names with more readable names
model_renames = {
    "gpt-3.5-turbo-0613": "GPT-3.5",
    "gpt-3.5-turbo-0613+gpt-3.5-turbo-0613": "GPT-3.5",
    "gpt-4-0613": "GPT-4", 
    "gpt-3.5-turbo-0613+reflexion": "GPT-3.5+reflexion",
    "gpt-3.5-turbo-0613+gpt-4-0613": "GPT-3.5, GPT-4",
    "gpt-4-0613+reflexion": "GPT-4+reflexion", 
    "l3_8b-gpt-3.5-turbo-0613-l3_70b-gpt4-0613": "gpt",
    "gpt-4-0613-5repeats-no-temp-incr": "GPT-4",
    "gpt-4-0613+gpt-4-0613": "GPT-4",
    "gpt-4-0613-5step": "GPT-4",
    # "gpt-3.5-turbo-0613-5repeats-no-temp-incr": "GPT-3.5",
    # "CL > GPT3.5 > GPT4": "CodeLlama"
}
data['model'] = data['model'].map(model_renames)

# Add model name to the strategy name
for i in range(data.shape[0]):
    print(data['strategy'][i])
    if strategy_renames[data['strategy'][i]] == "":
        data.loc[i, 'strategy_renamed'] = data['model'][i]
    elif strategy_renames[data['strategy'][i]] == "Escalation":
        data.loc[i, 'strategy_renamed'] = "Escalation"
    else:
        data.loc[i, 'strategy_renamed'] = str(data['strategy_renamed'][i]) + " (" + str(data['model'][i]) + ")"
    #if strategy is ldb and model contains reflexion, then add reflexion to the strategy name
    if data['strategy'][i] == "ldb" and "reflexion" in data['model'][i]:
        data.loc[i, 'strategy_renamed'] = "LDB" + " (" + str(data['model'][i]).replace("+reflexion", "") + ", Reflexion" + ")"


blue = sns.color_palette("Dark2")[0]
orange = sns.color_palette("Dark2")[1]
green = sns.color_palette("Dark2")[2]

# color_dict = {'GPT-4': blue,
#  'GPT-3.5': blue,
#  'LDB (GPT-4)': orange,
#  'LDB (GPT-3.5)': orange,
#  'Escalation': green,
#  'Reflexion (GPT-4)': orange,
#  "LATS (GPT-3.5)": orange,
#  "Retry (GPT-4)": green,
#  "Warming (GPT-4-1step)": blue,
#  "LDB (GPT-4, Reflexion)": orange,
#  "LDB (GPT-3.5, GPT-4)": orange,
#  "LATS (GPT-4)": orange,
#  "LDB (GPT-3.5, Reflexion)": orange,
#  "Reflexion (GPT-3.5)": orange,
#  "Repeat (GPT-3.5)": green,
# "Warming (GPT-4)": green}


# # Change colors of points based on strategy and model
# scatter_plot = sns.scatterplot(data=data, x='total_cost', y='accuracy', hue='strategy_renamed', palette=color_dict,
#                                 marker='o', s=200, legend=None)


# Group data by model and strategy, calculating mean and error bar ranges
grouped_data = data.groupby(['model', 'strategy_renamed']).agg(
    mean_accuracy=('accuracy', 'mean'),
    min_accuracy=('accuracy', 'min'),
    max_accuracy=('accuracy', 'max'),
    mean_cost=('total_cost', 'mean')
).reset_index()

# Calculate error bar values (max - mean and mean - min)
grouped_data['yerr_upper'] = grouped_data['max_accuracy'] - grouped_data['mean_accuracy']
grouped_data['yerr_lower'] = grouped_data['mean_accuracy'] - grouped_data['min_accuracy']


# Create the scatter plot with error bars
plt.figure(figsize=(12, 8))
scatter_plot = sns.scatterplot(
    data=grouped_data, 
    x='mean_cost', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None
)

# change color of the error bars
for i in range(len(grouped_data)):
    plt.errorbar(
        x=grouped_data['mean_cost'][i], 
        y=grouped_data['mean_accuracy'][i], 
        yerr=[[grouped_data['yerr_lower'][i]], [grouped_data['yerr_upper'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=color_dict[grouped_data['strategy_renamed'][i]],  # Use the same color as the scatter plot
        capsize=0,  # Add caps to the error bars
        elinewidth=3  # Adjust error bar line width
    )

# LEGEND
colors = [orange, green, blue]
labels = ['Complex agent', 'Baseline agent', 'Zero-shot model']
# Create empty scatter plots as legend handles
legend_handles = []
for color in colors:
    handle = plt.scatter([], [], c=color, marker='o')
    legend_handles.append(handle)
plt.legend(handles=legend_handles, labels=labels, loc="lower right")


# Setting the title and labels
# plt.title('Accuracy vs. Cost per Model and Agent on HumanEval', fontsize=16, pad=15)
plt.xlabel('Total Cost (USD, measured in April 2024)', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.grid(True)


# Setting the y-axis limits
plt.ylim(0.7, 1)
plt.xlim(0,20)
plt.xticks(range(0,20,2))
# plt.xscale('log', base=10)

data = grouped_data
# Implementing label adjustments using simple lines
for i in range(data.shape[0]):
    annotation_text = data.strategy_renamed[i]
    x = data.mean_cost[i]
    y = data.mean_accuracy[i]
    if data.strategy_renamed[i] == "Escalation":
        xytext = (45, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-3.5":
        xytext = (50, -15)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-3.5)":
        xytext = (90, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4)":
        xytext = (90, -15)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-3.5, Reflexion)":
        xytext = (160, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4, Reflexion)":
        xytext = (30, -35)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-3.5, GPT-4)":
        xytext = (15, 30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-3.5)":
        xytext = (110, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-4)":
        xytext = (-20, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4)":
        xytext = (90, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4-1step)":
        xytext = (10, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Retry (GPT-4)":
        xytext = (110,10)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-4":
        xytext = (40,-20)  # "Escalation" above the point
        ha = 'right'
    else:
        xytext = (30, -20)  # other strategies below the point to the right
        ha = 'right'

    scatter_plot.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))

plt.show()
# Out:
# simple
# simple
# simple
# simple
# simple
# simple
# simple
# simple
# simple
# simple
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# ldb
# simple_boosting
# simple_boosting
# simple_boosting
# simple_boosting
# simple_boosting
# reflexion
# reflexion
# reflexion
# reflexion
# reflexion
# simple_incr_temp
# simple_incr_temp
# simple_incr_temp
# simple_incr_temp
# simple_incr_temp
# simple_incr_temp
# simple_incr_temp
# simple_incr_temp
# simple_incr_temp
# simple_incr_temp
# simple_repeat
# simple_repeat
# simple_repeat
# simple_repeat
# simple_repeat
# simple_repeat
# simple_repeat
# simple_repeat
# simple_repeat
# simple_repeat
# /tmp/ipykernel_1777177/3842952131.py:131: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   handle = plt.scatter([], [], c=color, marker='o')

# %% [markdown]
# ## with cost CI

# %% [markdown]
# ### 0409

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

sns.set_style("whitegrid")
# Set the context for plotting 
sns.set_context("notebook", font_scale=1)  #

# Load the data
data = pd.read_csv('plot_data_0409.csv')


# Map the old strategy names to the new names
strategy_renames = {
    "ldb": "LDB",
    "lats": "LATS",
    "simple": "",
    "simple_boosting": "Escalation",
    "simple_incr_temp": "Warming",
    "reflexion": "Reflexion",
    "simple_repeat": "Retry"
}
data['strategy_renamed'] = data['strategy'].map(strategy_renames)

# Replace model names with more readable names
model_renames = {
    "gpt-3.5-turbo-0125": "GPT-3.5",
    "gpt-3.5-turbo-0125+gpt-3.5-turbo-0125": "GPT-3.5",
    "gpt-4-turbo-2024-04-09": "GPT-4",
    "gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09": "GPT-4",
    "gpt-4-turbo-0125": "GPT-4",
    "l3_8b-gpt35-l3_70b-gpt4": "gpt",
    "l3_8b-gpt35-l3_70b-gpt4-0409": "gpt",
    "gpt-4-turbo-0125": "GPT-4",
    "gpt-4-turbo-0409-5step": "GPT-4",
     "gpt-4-turbo-0409-1step": "GPT-4-1step",
     "gpt-4-turbo-0125-8repeats-no-temp-incr": "GPT-4",
     "gpt-4-turbo-2024-04-09+reflexion": "GPT-4+reflexion",
     "gpt-3.5-turbo-0125+reflexion": "GPT-3.5+reflexion",
     "gpt-4-turbo-0409-5repeats-no-temp-incr": "GPT-4",
     "gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09": "GPT-4, GPT-3.5",
    # "CL > GPT3.5 > GPT4": "CodeLlama"
}

data['model'] = data['model'].map(model_renames)

# Add model name to the strategy name
for i in range(data.shape[0]):
    if strategy_renames[data['strategy'][i]] == "":
        data.loc[i, 'strategy_renamed'] = data['model'][i]
    elif strategy_renames[data['strategy'][i]] == "Escalation":
        data.loc[i, 'strategy_renamed'] = "Escalation"
    else:
        data.loc[i, 'strategy_renamed'] = str(data['strategy_renamed'][i]) + " (" + str(data['model'][i]) + ")"
    #if strategy is ldb and model contains reflexion, then add reflexion to the strategy name
    if data['strategy'][i] == "ldb" and "reflexion" in data['model'][i]:
        data.loc[i, 'strategy_renamed'] = "LDB" + " (" + "Reflexion, " + str(data['model'][i]).replace("+reflexion", "") + ")"


blue = sns.color_palette("Dark2")[0]
orange = sns.color_palette("Dark2")[1]
green = sns.color_palette("Dark2")[2]
# Create the scatter plot with error bars
f, (ax, ax2) = plt.subplots(1,2, figsize=(31, 8), sharey=True, width_ratios=[11, 31])
f.subplots_adjust(wspace=0.012)

# Additional function to calculate confidence intervals for cost
def calculate_cost_confidence_interval(data):
    n = len(data)
    mean = data.mean()
    std_err = stats.sem(data)  # Standard error for the cost data
    margin_of_error = std_err * stats.t.ppf((1 + 0.95) / 2., n - 1)  # 95% CI
    confidence_interval = (mean - margin_of_error, mean + margin_of_error)
    return confidence_interval

# Modify grouping to include cost confidence intervals
grouped_data = data.groupby(['model', 'strategy_renamed']).agg(
    mean_accuracy=('accuracy', 'mean'),
    mean_cost=('total_cost', 'mean'),
    max_cost=('total_cost', 'max'),
    min_cost=('total_cost', 'min'),
    cost_confidence_interval=('total_cost', calculate_cost_confidence_interval)
).reset_index()

# Calculate error bar values (max - mean and mean - min)
grouped_data['yerr_upper_maxmin'] = grouped_data['max_cost'] - grouped_data['mean_cost']
grouped_data['yerr_lower_maxmin'] = grouped_data['mean_cost'] - grouped_data['min_cost']

# Extract cost confidence interval values for error bars
grouped_data['xerr_lower_95CI'] = grouped_data['mean_cost'] - grouped_data['cost_confidence_interval'].str[0]
grouped_data['xerr_upper_95CI'] = grouped_data['cost_confidence_interval'].str[1] - grouped_data['mean_cost']

err_bar_offset = 0.0013
err_bar_line_width = 3
err_bar_alpha=0.5
# Adding horizontal error bars for cost on the plot
for i in range(len(grouped_data)):
    ax.errorbar(
        x=grouped_data['mean_cost'][i], 
        y=grouped_data['mean_accuracy'][i] - err_bar_offset, 
        xerr=[[grouped_data['xerr_lower_95CI'][i]], [grouped_data['xerr_upper_95CI'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=sns.color_palette("Dark2")[-2],  # Change color to gray for distinction
        capsize=0,  # Add caps to the error bars
        elinewidth=err_bar_line_width,  # Adjust error bar line width
        alpha=err_bar_alpha,  # Set transparency
        zorder=1
    )
    ax2.errorbar(
        x=grouped_data['mean_cost'][i], 
        y=grouped_data['mean_accuracy'][i] - err_bar_offset, 
        xerr=[[grouped_data['xerr_lower_95CI'][i]], [grouped_data['xerr_upper_95CI'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=sns.color_palette("Dark2")[-2],  # Change color to gray for distinction
        capsize=0,  # Add caps to the error bars
        elinewidth=err_bar_line_width,  # Adjust error bar line width
        alpha=err_bar_alpha,  # Set transparency
        zorder=1
    )
# Adding horizontal error bars for cost on the plot
for i in range(len(grouped_data)):
    ax.errorbar(
        x=grouped_data['mean_cost'][i], 
        y=grouped_data['mean_accuracy'][i] + err_bar_offset, 
        xerr=[[grouped_data['yerr_lower_maxmin'][i]], [grouped_data['yerr_upper_maxmin'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=sns.color_palette("Dark2")[-1],  # Change color to gray for distinction
        capsize=0,  # Add caps to the error bars
        elinewidth=err_bar_line_width,  # Adjust error bar line width
        alpha=err_bar_alpha,  # Set transparency
        zorder=1
    )
    ax2.errorbar(
        x=grouped_data['mean_cost'][i], 
        y=grouped_data['mean_accuracy'][i] + err_bar_offset, 
        xerr=[[grouped_data['yerr_lower_maxmin'][i]], [grouped_data['yerr_upper_maxmin'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=sns.color_palette("Dark2")[-1],  # Change color to gray for distinction
        capsize=0,  # Add caps to the error bars
        elinewidth=err_bar_line_width,  # Adjust error bar line width
        alpha=err_bar_alpha,  # Set transparency
        zorder=1
    )





# Group data and calculate confidence intervals
def calculate_confidence_interval(data):
    n = len(data)
    mean = data.mean()
    std_err = stats.sem(data)  # Calculate standard error
    margin_of_error = std_err * stats.t.ppf((1 + 0.95) / 2, n - 1)  # 95% CI
    confidence_interval = (mean - margin_of_error, mean + margin_of_error)
    return confidence_interval

grouped_data = data.groupby(['model', 'strategy_renamed']).agg(
    mean_accuracy=('accuracy', 'mean'),
    min_accuracy=('accuracy', 'min'),
    max_accuracy=('accuracy', 'max'),
    mean_cost=('total_cost', 'mean'),
    confidence_interval=('accuracy', calculate_confidence_interval)
).reset_index()


# Calculate error bar values (max - mean and mean - min)
grouped_data['yerr_upper_maxmin'] = grouped_data['max_accuracy'] - grouped_data['mean_accuracy']
grouped_data['yerr_lower_maxmin'] = grouped_data['mean_accuracy'] - grouped_data['min_accuracy']

# Extract confidence interval values
grouped_data['yerr_lower_95CI'] = grouped_data['mean_accuracy'] - grouped_data['confidence_interval'].str[0]
grouped_data['yerr_upper_95CI'] = grouped_data['confidence_interval'].str[1] - grouped_data['mean_accuracy']


# Create the scatter plot with error bars
scatter_plot = sns.scatterplot(
    data=grouped_data, 
    x='mean_cost', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None,
    zorder=2,
    ax=ax,
    edgecolor='none'
)
# Create the scatter plot with error bars
scatter_plot2 = sns.scatterplot(
    data=grouped_data, 
    x='mean_cost', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None,
    zorder=2,
    ax=ax2,
    edgecolor='none'
)


err_bar_offset = 0.03
# change color of the error bars
for i in range(len(grouped_data)):
    ax.errorbar(
        x=grouped_data['mean_cost'][i] - err_bar_offset, 
        y=grouped_data['mean_accuracy'][i], 
        yerr=[[grouped_data['yerr_lower_95CI'][i]], [grouped_data['yerr_upper_95CI'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=sns.color_palette("Dark2")[-2],  # Use the same color as the scatter plot
        capsize=0,  # Add caps to the error bars
        elinewidth=err_bar_line_width,  # Adjust error bar line width,
        label="95% CI",
        zorder=1,
        alpha=err_bar_alpha
    )
    ax2.errorbar(
        x=grouped_data['mean_cost'][i] - err_bar_offset, 
        y=grouped_data['mean_accuracy'][i], 
        yerr=[[grouped_data['yerr_lower_95CI'][i]], [grouped_data['yerr_upper_95CI'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=sns.color_palette("Dark2")[-2],  # Use the same color as the scatter plot
        capsize=0,  # Add caps to the error bars
        elinewidth=err_bar_line_width,  # Adjust error bar line width,
        label="95% CI",
        zorder=1,
        alpha=err_bar_alpha
    )

# change color of the error bars
for i in range(len(grouped_data)):
    ax.errorbar(
        x=grouped_data['mean_cost'][i] + err_bar_offset, 
        y=grouped_data['mean_accuracy'][i], 
        yerr=[[grouped_data['yerr_lower_maxmin'][i]], [grouped_data['yerr_upper_maxmin'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=sns.color_palette("Dark2")[-1],  # Use the same color as the scatter plot
        capsize=0,  # Add caps to the error bars
        elinewidth=err_bar_line_width,  # Adjust error bar line width,
        label="max-min",
        zorder=1,
        alpha=err_bar_alpha
    )
    ax2.errorbar(
        x=grouped_data['mean_cost'][i] + err_bar_offset, 
        y=grouped_data['mean_accuracy'][i], 
        yerr=[[grouped_data['yerr_lower_maxmin'][i]], [grouped_data['yerr_upper_maxmin'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=sns.color_palette("Dark2")[-1],  # Use the same color as the scatter plot
        capsize=0,  # Add caps to the error bars
        elinewidth=err_bar_line_width,  # Adjust error bar line width,
        label="max-min",
        zorder=1,
        alpha=err_bar_alpha
    )
# LEGEND
colors = [sns.color_palette("Dark2")[-2], sns.color_palette("Dark2")[-1]]
labels = ['95% CI', 'Min-Max']
# Create empty scatter plots as legend handles
legend_handles = []
for color in colors:
    handle = plt.scatter([], [], c=color, marker='|', s=160, linewidth=5, alpha=err_bar_alpha)
    legend_handles.append(handle)
plt.gca().add_artist(plt.legend(handles=legend_handles, labels=labels, bbox_to_anchor=(1, 0.235)))

# LEGEND
colors = [orange, green, blue]
labels = ['Complex agent', 'Baseline agent', 'Zero-shot model']
# Create empty scatter plots as legend handles
legend_handles = []
for color in colors:
    handle = plt.scatter([], [], c=color, marker='o')
    legend_handles.append(handle)
plt.gca().add_artist(plt.legend(handles=legend_handles, labels=labels, loc="lower right"))


# Setting the title and labels
# plt.title('Accuracy vs. Cost per Model and Agent on HumanEval', fontsize=16, pad=15)
ax.set_ylabel('Accuracy', fontsize=14)
# set joint x-axis label
f.text(0.5, 0.05, 'Cost (USD, measured in April 2024)', ha='center', va='center', fontsize=14)
# remove the x-axis label from the second plot
ax2.set_xlabel('')
ax.set_xlabel('')
plt.grid(True)

# Setting the y-axis limits
plt.ylim(0.7, 1)
ax.set_xlim(0, 11)
ax2.set_xlim(119, 150)
# plt.xscale('log', base=10)

# plot ticks on x axis every 5 units
ax.set_xticks([0,5,10])
ax2.set_xticks([120, 125, 130, 135, 140, 145, 150])

ax.grid(False)
ax2.grid(False)

d = .02  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1 - d, 1 + d), (1 - d, 1 + d), zorder=3, **kwargs)     # top-left diagonal
ax.plot((1 - d, 1 + d), (-d, +d), zorder=3, **kwargs)  # top-right diagonal

d = .02
kwargs.update(transform=ax2.transAxes, color='k', clip_on=False)  # switch to the bottom axes
ax2.plot((-d+0.013, +d-0.013), (- d, + d), zorder=3, **kwargs)  # bottom-left diagonal
ax2.plot((- d+0.013, + d-0.013), (1 - d, 1 + d), zorder=3,**kwargs)  # bottom-right diagonal

ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

data = grouped_data
# Implementing label adjustments using simple lines
for i in range(data.shape[0]):
    annotation_text = data.strategy_renamed[i]
    x = data.mean_cost[i]
    y = data.mean_accuracy[i]
    if data.strategy_renamed[i] == "Escalation":
        xytext = (70, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-3.5":
        xytext = (50, -15)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-3.5)":
        xytext = (90, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4)":
        xytext = (-5, -25)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4, GPT-3.5)":
        xytext = (-10, 30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-3.5)":
        xytext = (160, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-4)":
        xytext = (140, -25)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-3.5)":
        xytext = (110, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-4)":
        xytext = (-10, -30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4)":
        xytext = (90, 30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LATS (GPT-4)":
        xytext = (-10, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LATS (GPT-3.5)":
        xytext = (-10, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Retry (GPT-4)":
        xytext = (100,20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-4":
        xytext = (-10,-20)  # "Escalation" above the point
        ha = 'right'
    else:
        xytext = (30, -20)  # other strategies below the point to the right
        ha = 'right'

    scatter_plot.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))
    scatter_plot2.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))

plt.show()
# Out:
# /tmp/ipykernel_1777177/3926837420.py:267: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   handle = plt.scatter([], [], c=color, marker='|', s=160, linewidth=5, alpha=err_bar_alpha)
# /tmp/ipykernel_1777177/3926837420.py:277: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   handle = plt.scatter([], [], c=color, marker='o')

# %% [markdown]
# ### 0613

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

sns.set_style("whitegrid")
# Set the context for plotting 
sns.set_context("notebook", font_scale=1)  #

# Load the data
data = pd.read_csv('plot_data_0613.csv')

# Drop LATS
data = data[~((data['strategy'] == 'lats'))].reset_index(drop=True)

# Map the old strategy names to the new names
strategy_renames = {
    "ldb": "LDB",
    "lats": "LATS",
    "simple": "",
    "simple_boosting": "Escalation",
    "simple_incr_temp": "Warming",
    "reflexion": "Reflexion",
    "simple_repeat": "Retry"
}
data['strategy_renamed'] = data['strategy'].map(strategy_renames)

# Replace model names with more readable names
model_renames = {
    "gpt-3.5-turbo-0613": "GPT-3.5",
    "gpt-3.5-turbo-0613+gpt-3.5-turbo-0613": "GPT-3.5",
    "gpt-4-0613": "GPT-4", 
    "gpt-3.5-turbo-0613+reflexion": "GPT-3.5+reflexion",
    "gpt-3.5-turbo-0613+gpt-4-0613": "GPT-4, GPT-3.5",
    "gpt-4-0613+reflexion": "GPT-4+reflexion", 
    "l3_8b-gpt-3.5-turbo-0613-l3_70b-gpt4-0613": "gpt",
    "gpt-4-0613-5repeats-no-temp-incr": "GPT-4",
    "gpt-4-0613+gpt-4-0613": "GPT-4",
    "gpt-4-0613-5step": "GPT-4",
    # "gpt-3.5-turbo-0613-5repeats-no-temp-incr": "GPT-3.5",
    # "CL > GPT3.5 > GPT4": "CodeLlama"
}


data['model'] = data['model'].map(model_renames)

# Add model name to the strategy name
for i in range(data.shape[0]):
    if strategy_renames[data['strategy'][i]] == "":
        data.loc[i, 'strategy_renamed'] = data['model'][i]
    elif strategy_renames[data['strategy'][i]] == "Escalation":
        data.loc[i, 'strategy_renamed'] = "Escalation"
    else:
        data.loc[i, 'strategy_renamed'] = str(data['strategy_renamed'][i]) + " (" + str(data['model'][i]) + ")"
    #if strategy is ldb and model contains reflexion, then add reflexion to the strategy name
    if data['strategy'][i] == "ldb" and "reflexion" in data['model'][i]:
        data.loc[i, 'strategy_renamed'] = "LDB" + " (" + "Reflexion, " + str(data['model'][i]).replace("+reflexion", "") + ")"


blue = sns.color_palette("Dark2")[0]
orange = sns.color_palette("Dark2")[1]
green = sns.color_palette("Dark2")[2]
plt.figure(figsize=(12, 8))

# Additional function to calculate confidence intervals for cost
def calculate_cost_confidence_interval(data):
    n = len(data)
    mean = data.mean()
    std_err = stats.sem(data)  # Standard error for the cost data
    margin_of_error = std_err * stats.t.ppf((1 + 0.95) / 2., n - 1)  # 95% CI
    confidence_interval = (mean - margin_of_error, mean + margin_of_error)
    return confidence_interval

# Modify grouping to include cost confidence intervals
grouped_data = data.groupby(['model', 'strategy_renamed']).agg(
    mean_accuracy=('accuracy', 'mean'),
    mean_cost=('total_cost', 'mean'),
    max_cost=('total_cost', 'max'),
    min_cost=('total_cost', 'min'),
    cost_confidence_interval=('total_cost', calculate_cost_confidence_interval)
).reset_index()

# Calculate error bar values (max - mean and mean - min)
grouped_data['yerr_upper_maxmin'] = grouped_data['max_cost'] - grouped_data['mean_cost']
grouped_data['yerr_lower_maxmin'] = grouped_data['mean_cost'] - grouped_data['min_cost']

# Extract cost confidence interval values for error bars
grouped_data['xerr_lower_95CI'] = grouped_data['mean_cost'] - grouped_data['cost_confidence_interval'].str[0]
grouped_data['xerr_upper_95CI'] = grouped_data['cost_confidence_interval'].str[1] - grouped_data['mean_cost']


err_bar_offset = 0.0013
err_bar_line_width = 3
err_bar_alpha=0.5
# Adding horizontal error bars for cost on the plot
for i in range(len(grouped_data)):
    plt.errorbar(
        x=grouped_data['mean_cost'][i], 
        y=grouped_data['mean_accuracy'][i] - err_bar_offset, 
        xerr=[[grouped_data['xerr_lower_95CI'][i]], [grouped_data['xerr_upper_95CI'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=sns.color_palette("Dark2")[-2],  # Change color to gray for distinction
        capsize=0,  # Add caps to the error bars
        elinewidth=err_bar_line_width,  # Adjust error bar line width
        alpha=err_bar_alpha,  # Set transparency
        zorder=1
    )
# Adding horizontal error bars for cost on the plot
for i in range(len(grouped_data)):
    plt.errorbar(
        x=grouped_data['mean_cost'][i], 
        y=grouped_data['mean_accuracy'][i] + err_bar_offset, 
        xerr=[[grouped_data['yerr_lower_maxmin'][i]], [grouped_data['yerr_upper_maxmin'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=sns.color_palette("Dark2")[-1],  # Change color to gray for distinction
        capsize=0,  # Add caps to the error bars
        elinewidth=err_bar_line_width,  # Adjust error bar line width
        alpha=err_bar_alpha,  # Set transparency
        zorder=1
    )





# Group data and calculate confidence intervals
def calculate_confidence_interval(data):
    n = len(data)
    mean = data.mean()
    std_err = stats.sem(data)  # Calculate standard error
    margin_of_error = std_err * stats.t.ppf((1 + 0.95) / 2, n - 1)  # 95% CI
    confidence_interval = (mean - margin_of_error, mean + margin_of_error)
    return confidence_interval

grouped_data = data.groupby(['model', 'strategy_renamed']).agg(
    mean_accuracy=('accuracy', 'mean'),
    min_accuracy=('accuracy', 'min'),
    max_accuracy=('accuracy', 'max'),
    mean_cost=('total_cost', 'mean'),
    confidence_interval=('accuracy', calculate_confidence_interval)
).reset_index()


# Calculate error bar values (max - mean and mean - min)
grouped_data['yerr_upper_maxmin'] = grouped_data['max_accuracy'] - grouped_data['mean_accuracy']
grouped_data['yerr_lower_maxmin'] = grouped_data['mean_accuracy'] - grouped_data['min_accuracy']

# Extract confidence interval values
grouped_data['yerr_lower_95CI'] = grouped_data['mean_accuracy'] - grouped_data['confidence_interval'].str[0]
grouped_data['yerr_upper_95CI'] = grouped_data['confidence_interval'].str[1] - grouped_data['mean_accuracy']


# Create the scatter plot with error bars
scatter_plot = sns.scatterplot(
    data=grouped_data, 
    x='mean_cost', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None,
    zorder=2,
    edgecolor='none'
)


err_bar_offset = 0.03
# change color of the error bars
for i in range(len(grouped_data)):
    plt.errorbar(
        x=grouped_data['mean_cost'][i] - err_bar_offset, 
        y=grouped_data['mean_accuracy'][i], 
        yerr=[[grouped_data['yerr_lower_95CI'][i]], [grouped_data['yerr_upper_95CI'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=sns.color_palette("Dark2")[-2],  # Use the same color as the scatter plot
        capsize=0,  # Add caps to the error bars
        elinewidth=err_bar_line_width,  # Adjust error bar line width,
        label="95% CI",
        zorder=1,
        alpha=err_bar_alpha
    )

# change color of the error bars
for i in range(len(grouped_data)):
    plt.errorbar(
        x=grouped_data['mean_cost'][i] + err_bar_offset, 
        y=grouped_data['mean_accuracy'][i], 
        yerr=[[grouped_data['yerr_lower_maxmin'][i]], [grouped_data['yerr_upper_maxmin'][i]]], 
        fmt='o',  # Use the same marker as the scatter plot
        color=sns.color_palette("Dark2")[-1],  # Use the same color as the scatter plot
        capsize=0,  # Add caps to the error bars
        elinewidth=err_bar_line_width,  # Adjust error bar line width,
        label="max-min",
        zorder=1,
        alpha=err_bar_alpha
    )
# LEGEND
colors = [sns.color_palette("Dark2")[-2], sns.color_palette("Dark2")[-1]]
labels = ['95% CI', 'Min-Max']
# Create empty scatter plots as legend handles
legend_handles = []
for color in colors:
    handle = plt.scatter([], [], c=color, marker='|', s=160, linewidth=5, alpha=err_bar_alpha)
    legend_handles.append(handle)
plt.gca().add_artist(plt.legend(handles=legend_handles, labels=labels, bbox_to_anchor=(1, 0.235)))

# LEGEND
colors = [orange, green, blue]
labels = ['Complex agent', 'Baseline agent', 'Zero-shot model']
# Create empty scatter plots as legend handles
legend_handles = []
for color in colors:
    handle = plt.scatter([], [], c=color, marker='o')
    legend_handles.append(handle)
plt.gca().add_artist(plt.legend(handles=legend_handles, labels=labels, loc="lower right"))




# Setting the title and labels
# plt.title('Accuracy vs. Cost per Model and Agent on HumanEval', fontsize=16, pad=15)
plt.xlabel('Total Cost (USD, measured in April 2024)', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.grid(True)


# Setting the y-axis limits
plt.ylim(0.7, 1)
plt.xlim(0,22)
# convert x axis labels to integer
plt.xticks(range(0, 22,2))

# plt.xscale('log', base=10)

data = grouped_data
# Implementing label adjustments using simple lines
for i in range(data.shape[0]):
    annotation_text = data.strategy_renamed[i]
    x = data.mean_cost[i]
    y = data.mean_accuracy[i]
    if data.strategy_renamed[i] == "Escalation":
        xytext = (45, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-3.5":
        xytext = (50, -15)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-3.5)":
        xytext = (90, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4)":
        xytext = (90, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4, GPT-3.5)":
        xytext = (10, 30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-3.5)":
        xytext = (140, -30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-4)":
        xytext = (30, -35)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-3.5)":
        xytext = (110, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-4)":
        xytext = (-20, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4)":
        xytext = (90, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4-1step)":
        xytext = (10, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Retry (GPT-4)":
        xytext = (110,10)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-4":
        xytext = (40,-20)  # "Escalation" above the point
        ha = 'right'
    else:
        xytext = (30, -20)  # other strategies below the point to the right
        ha = 'right'

    scatter_plot.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))

plt.show()
# Out:
# /tmp/ipykernel_1777177/4126266198.py:204: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   handle = plt.scatter([], [], c=color, marker='|', s=160, linewidth=5, alpha=err_bar_alpha)
# /tmp/ipykernel_1777177/4126266198.py:214: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   handle = plt.scatter([], [], c=color, marker='o')

# %% [markdown]
# ## with LATS broken x axis

# %% [markdown]
# ### 0409

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

sns.set_style("whitegrid")
# Set the context for plotting 
sns.set_context("notebook", font_scale=1)  #

# Load the data
data = pd.read_csv('plot_data_0409.csv')


# Map the old strategy names to the new names
strategy_renames = {
    "ldb": "LDB",
    "lats": "LATS",
    "simple": "",
    "simple_boosting": "Escalation",
    "simple_incr_temp": "Warming",
    "reflexion": "Reflexion",
    "simple_repeat": "Retry"
}
data['strategy_renamed'] = data['strategy'].map(strategy_renames)

# Replace model names with more readable names
model_renames = {
    "gpt-3.5-turbo-0125": "GPT-3.5",
    "gpt-3.5-turbo-0125+gpt-3.5-turbo-0125": "GPT-3.5",
    "gpt-4-turbo-2024-04-09": "GPT-4",
    "gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09": "GPT-4",
    "gpt-4-turbo-0125": "GPT-4",
    "l3_8b-gpt35-l3_70b-gpt4": "gpt",
    "l3_8b-gpt35-l3_70b-gpt4-0409": "gpt",
    "gpt-4-turbo-0125": "GPT-4",
    "gpt-4-turbo-0409-5step": "GPT-4",
     "gpt-4-turbo-0409-1step": "GPT-4-1step",
     "gpt-4-turbo-0125-8repeats-no-temp-incr": "GPT-4",
     "gpt-4-turbo-2024-04-09+reflexion": "GPT-4+reflexion",
     "gpt-3.5-turbo-0125+reflexion": "GPT-3.5+reflexion",
     "gpt-4-turbo-0409-5repeats-no-temp-incr": "GPT-4",
     "gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09": "GPT-4, GPT-3.5",
    # "CL > GPT3.5 > GPT4": "CodeLlama"
}

data['model'] = data['model'].map(model_renames)

# Add model name to the strategy name
for i in range(data.shape[0]):
    if strategy_renames[data['strategy'][i]] == "":
        data.loc[i, 'strategy_renamed'] = data['model'][i]
    elif strategy_renames[data['strategy'][i]] == "Escalation":
        data.loc[i, 'strategy_renamed'] = "Escalation"
    else:
        data.loc[i, 'strategy_renamed'] = str(data['strategy_renamed'][i]) + " (" + str(data['model'][i]) + ")"
    #if strategy is ldb and model contains reflexion, then add reflexion to the strategy name
    if data['strategy'][i] == "ldb" and "reflexion" in data['model'][i]:
        data.loc[i, 'strategy_renamed'] = "LDB" + " (" + "Reflexion, " + str(data['model'][i]).replace("+reflexion", "") + ")"




# # Change colors of points based on strategy and model
# scatter_plot = sns.scatterplot(data=data, x='total_cost', y='accuracy', hue='strategy_renamed', palette=color_dict,
#                                 marker='o', s=200, legend=None)


# Group data by model and strategy, calculating mean and error bar ranges
grouped_data = data.groupby(['model', 'strategy_renamed']).agg(
    mean_accuracy=('accuracy', 'mean'),
    min_accuracy=('accuracy', 'min'),
    max_accuracy=('accuracy', 'max'),
    mean_cost=('total_cost', 'mean')
).reset_index()

# Calculate error bar values (max - mean and mean - min)
grouped_data['yerr_upper'] = grouped_data['max_accuracy'] - grouped_data['mean_accuracy']
grouped_data['yerr_lower'] = grouped_data['mean_accuracy'] - grouped_data['min_accuracy']


# Create the scatter plot with error bars
f, (ax, ax2) = plt.subplots(1,2, figsize=(12, 8), sharey=True, width_ratios=[11, 6])
f.subplots_adjust(wspace=0.03)

scatter_plot = sns.scatterplot(
    data=grouped_data, 
    x='mean_cost', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None,
    ax=ax,
    zorder=2
)
scatter_plot2 = sns.scatterplot(
    data=grouped_data, 
    x='mean_cost', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None,
    ax=ax2,
    zorder=2
)

# # change color of the error bars
# for i in range(len(grouped_data)):
#     plt.errorbar(
#         x=grouped_data['mean_cost'][i], 
#         y=grouped_data['mean_accuracy'][i], 
#         yerr=[[grouped_data['yerr_lower'][i]], [grouped_data['yerr_upper'][i]]], 
#         fmt='o',  # Use the same marker as the scatter plot
#         color=color_dict[grouped_data['strategy_renamed'][i]],  # Use the same color as the scatter plot
#         capsize=0,  # Add caps to the error bars
#         elinewidth=3  # Adjust error bar line width
#     )


# Setting the title and labels
# plt.title('Accuracy vs. Cost per Model and Agent on HumanEval', fontsize=16, pad=15)
ax.set_ylabel('Accuracy', fontsize=14)
# set joint x-axis label
f.text(0.5, 0.05, 'Cost (USD, measured in April 2024)', ha='center', va='center', fontsize=14)
# remove the x-axis label from the second plot
ax2.set_xlabel('')
ax.set_xlabel('')
plt.grid(True)

# Setting the y-axis limits
plt.ylim(0.7, 1)
ax.set_xlim(0, 11)
ax2.set_xlim(129, 135)
# plt.xscale('log', base=10)

# plot ticks on x axis every 5 units
ax.set_xticks([0,5,10])
ax2.set_xticks([130, 135])

ax.grid(False)
ax2.grid(False)

d = .02  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1 - d, 1 + d), (1 - d, 1 + d), zorder=3, **kwargs)     # top-left diagonal
ax.plot((1 - d, 1 + d), (-d, +d), zorder=3, **kwargs)  # top-right diagonal

d = .02
kwargs.update(transform=ax2.transAxes, color='k', clip_on=False)  # switch to the bottom axes
ax2.plot((-d-0.013, +d+0.013), (- d, + d), zorder=3, **kwargs)  # bottom-left diagonal
ax2.plot((- d-0.013, + d+0.013), (1 - d, 1 + d), zorder=3,**kwargs)  # bottom-right diagonal

ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

# LEGEND
colors = [orange, green, blue]
labels = ['Complex agent', 'Baseline agent', 'Zero-shot model']
# Create empty scatter plots as legend handles
legend_handles = []
for color in colors:
    handle = plt.scatter([], [], c=color, marker='o')
    legend_handles.append(handle)
ax2.legend(handles=legend_handles, labels=labels, loc="lower right")

# Define the points for the Pareto frontier line
pareto_color = "black"
pareto_x = [0.054854, 0.273124, 2.448440]
pareto_y = [0.739024, 0.85, 0.931707]
ax.plot(pareto_x, pareto_y, linestyle='dashed', color=pareto_color, zorder=1, linewidth=1, dashes=(10, 4))
ax.text(pareto_x[1]+0.01, pareto_y[1]+0.012, 'Pareto frontier', fontsize=12, color=pareto_color, ha='left', va='bottom', rotation=56) # log scale
# plt.text(pareto_x[0]+0.022, pareto_y[0]+0.035, 'Pareto frontier', fontsize=12, color=pareto_color, ha='left', va='bottom', rotation=54)

data = grouped_data
# Implementing label adjustments using simple lines
for i in range(data.shape[0]):
    annotation_text = data.strategy_renamed[i]
    x = data.mean_cost[i]
    y = data.mean_accuracy[i]
    if data.strategy_renamed[i] == "Escalation":
        xytext = (65, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-3.5":
        xytext = (60, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-3.5)":
        xytext = (90, -30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-3.5)":
        xytext = (90, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-4)":
        xytext = (70, -30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-4)":
        xytext = (120, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-3.5)":
        xytext = (170, -10)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4)":
        xytext = (70, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4, GPT-3.5)":
        xytext = (130, -10)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4)":
        xytext = (70, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4-1step)":
        xytext = (60, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Retry (GPT-4)":
        xytext = (110,0)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-4":
        xytext = (30,-20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LATS (GPT-3.5)":
        xytext = (20,-20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LATS (GPT-4)":
        xytext = (0,-20)  # "Escalation" above the point
        ha = 'right'
    else:
        xytext = (60, -5)  # other strategies below the point to the right
        ha = 'right'

    scatter_plot.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))
    scatter_plot2.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))

plt.show()
# Out:
# /tmp/ipykernel_1777177/410154414.py:166: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   handle = plt.scatter([], [], c=color, marker='o')

# %% [markdown]
# ### time

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

sns.set_style("whitegrid")
# Set the context for plotting 
sns.set_context("notebook", font_scale=1)  #

# Load the data
data = pd.read_csv('plot_data_0409.csv')

data['strategy_renamed'] = data['strategy'].map(strategy_renames)


data['model'] = data['model'].map(model_renames)

# Add model name to the strategy name
for i in range(data.shape[0]):
    if strategy_renames[data['strategy'][i]] == "":
        data.loc[i, 'strategy_renamed'] = data['model'][i]
    elif strategy_renames[data['strategy'][i]] == "Escalation":
        data.loc[i, 'strategy_renamed'] = "Escalation"
    else:
        data.loc[i, 'strategy_renamed'] = str(data['strategy_renamed'][i]) + " (" + str(data['model'][i]) + ")"
    #if strategy is ldb and model contains reflexion, then add reflexion to the strategy name
    if data['strategy'][i] == "ldb" and "reflexion" in data['model'][i]:
        data.loc[i, 'strategy_renamed'] = "LDB" + " (" + "Reflexion, " + str(data['model'][i]).replace("+reflexion", "") + ")"




# # Change colors of points based on strategy and model
# scatter_plot = sns.scatterplot(data=data, x='total_cost', y='accuracy', hue='strategy_renamed', palette=color_dict,
#                                 marker='o', s=200, legend=None)


# Group data by model and strategy, calculating mean and error bar ranges
grouped_data = data.groupby(['model', 'strategy_renamed']).agg(
    mean_accuracy=('accuracy', 'mean'),
    min_accuracy=('accuracy', 'min'),
    max_accuracy=('accuracy', 'max'),
    mean_time=('total_inference_time', 'mean')
).reset_index()

# Calculate error bar values (max - mean and mean - min)
grouped_data['yerr_upper'] = grouped_data['max_accuracy'] - grouped_data['mean_accuracy']
grouped_data['yerr_lower'] = grouped_data['mean_accuracy'] - grouped_data['min_accuracy']


# Create the scatter plot with error bars
f, (ax, ax2, ax3) = plt.subplots(1,3, figsize=(12, 8), sharey=True, width_ratios=[6, 2, 1.5])
f.subplots_adjust(wspace=0.03)

scatter_plot = sns.scatterplot(
    data=grouped_data, 
    x='mean_time', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None,
    ax=ax,
    zorder=2
)
scatter_plot2 = sns.scatterplot(
    data=grouped_data, 
    x='mean_time', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None,
    ax=ax2,
    zorder=2
)
scatter_plot3 = sns.scatterplot(
    data=grouped_data, 
    x='mean_time', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None,
    ax=ax3,
    zorder=2
)

# # change color of the error bars
# for i in range(len(grouped_data)):
#     plt.errorbar(
#         x=grouped_data['mean_cost'][i], 
#         y=grouped_data['mean_accuracy'][i], 
#         yerr=[[grouped_data['yerr_lower'][i]], [grouped_data['yerr_upper'][i]]], 
#         fmt='o',  # Use the same marker as the scatter plot
#         color=color_dict[grouped_data['strategy_renamed'][i]],  # Use the same color as the scatter plot
#         capsize=0,  # Add caps to the error bars
#         elinewidth=3  # Adjust error bar line width
#     )


# Setting the title and labels
# plt.title('Accuracy vs. Cost per Model and Agent on HumanEval', fontsize=16, pad=15)
ax.set_ylabel('Accuracy', fontsize=14)
# set joint x-axis label
f.text(0.5, 0.05, 'Time (Seconds, measured in April 2024)', ha='center', va='center', fontsize=14)
# remove the x-axis label from the second plot
ax.set_xlabel('')
ax2.set_xlabel('')
ax3.set_xlabel('')
plt.grid(True)

# Setting the y-axis limits
plt.ylim(0.7, 1)
ax.set_xlim(0, 6000)
ax2.set_xlim(19500, 21500)
ax3.set_xlim(55500, 57000)
# plt.xscale('log', base=10)

ax.grid(False)
ax2.grid(False)
ax3.grid(False)

# plot ticks on x axis every 5 units
ax.set_xticks([0,1000,2000,3000,4000,5000])
ax2.set_xticks([20000,21000])
ax3.set_xticks([56000,57000])

d = .02  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1 - d+0.008, 1 + d-0.008), (1 - d, 1 + d), zorder=3, **kwargs)     # top-left diagonal
ax.plot((1 - d+0.008, 1 + d-0.008), (-d, +d), zorder=3, **kwargs)  # top-right diagonal

kwargs = dict(transform=ax2.transAxes, color='k', clip_on=False)
ax2.plot((1 - d-0.015, 1 + d+0.015), (1 - d, 1 + d), zorder=3, **kwargs)     # top-left diagonal
ax2.plot((1 - d-0.015, 1 + d+0.015), (-d, +d), zorder=3, **kwargs)  # top-right diagonal

kwargs.update(transform=ax2.transAxes, color='k', clip_on=False)  # switch to the bottom axes
ax2.plot((-d-0.015, +d+0.015), (- d, + d), zorder=3, **kwargs)  # bottom-left diagonal
ax2.plot((- d-0.015, + d+0.015), (1 - d, 1 + d), zorder=3,**kwargs)  # bottom-right diagonal

kwargs.update(transform=ax3.transAxes, color='k', clip_on=False)  # switch to the bottom axes
ax3.plot((-d-0.025, +d+0.025), (- d, + d), zorder=3, **kwargs)  # bottom-left diagonal
ax3.plot((- d-0.025, + d+0.025), (1 - d, 1 + d), zorder=3,**kwargs)  # bottom-right diagonal

ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax3.spines['left'].set_visible(False)

# LEGEND
colors = [orange, green, blue]
labels = ['Complex agent', 'Baseline agent', 'Zero-shot model']
# Create empty scatter plots as legend handles
legend_handles = []
for color in colors:
    handle = plt.scatter([], [], c=color, marker='o')
    legend_handles.append(handle)
ax3.legend(handles=legend_handles, labels=labels, bbox_to_anchor=(1, 0.18))

# Define the points for the Pareto frontier line
# pareto_color = "black"
# pareto_x = [326.559755, 553.508508, 2772.993986]
# pareto_y = [0.739024, 0.85, 0.931707]
# ax.plot(pareto_x, pareto_y, linestyle='dashed', color=pareto_color, zorder=1, linewidth=1, dashes=(10, 4))
# ax.text(pareto_x[1]+0.01, pareto_y[1]+0.006, 'Pareto frontier', fontsize=12, color=pareto_color, ha='left', va='bottom', rotation=33) # log scale
# plt.text(pareto_x[0]+0.022, pareto_y[0]+0.035, 'Pareto frontier', fontsize=12, color=pareto_color, ha='left', va='bottom', rotation=54)

data = grouped_data
# Implementing label adjustments using simple lines
for i in range(data.shape[0]):
    annotation_text = data.strategy_renamed[i]
    x = data.mean_time[i]
    y = data.mean_accuracy[i]
    if data.strategy_renamed[i] == "Escalation":
        xytext = (65, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-3.5":
        xytext = (60, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-3.5)":
        xytext = (90, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-3.5)":
        xytext = (110, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-4)":
        xytext = (20, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-4)":
        xytext = (40, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-3.5)":
        xytext = (120, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4)":
        xytext = (50, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4, GPT-3.5)":
        xytext = (0, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4)":
        xytext = (70, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4-1step)":
        xytext = (60, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Retry (GPT-4)":
        xytext = (100,15)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-4":
        xytext = (30,-20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LATS (GPT-3.5)":
        xytext = (70,-20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LATS (GPT-4)":
        xytext = (0,-20)  # "Escalation" above the point
        ha = 'right'
    else:
        xytext = (60, -5)  # other strategies below the point to the right
        ha = 'right'

    scatter_plot.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))
    scatter_plot2.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))
    scatter_plot3.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))

plt.show()
# Out:
# /tmp/ipykernel_1777177/2516781071.py:161: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   handle = plt.scatter([], [], c=color, marker='o')

# %% [markdown]
# ### 0613

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

sns.set_style("whitegrid")
# Set the context for plotting 
sns.set_context("notebook", font_scale=1)  #

# Load the data
data = pd.read_csv('plot_data_0613.csv')


# Map the old strategy names to the new names
strategy_renames = {
    "ldb": "LDB",
    "lats": "LATS",
    "simple": "",
    "simple_boosting": "Escalation",
    "simple_incr_temp": "Warming",
    "reflexion": "Reflexion",
    "simple_repeat": "Retry"
}
data['strategy_renamed'] = data['strategy'].map(strategy_renames)

# Replace model names with more readable names
model_renames = {
    "gpt-3.5-turbo-0613": "GPT-3.5",
    "gpt-3.5-turbo-0613+gpt-3.5-turbo-0613": "GPT-3.5",
    "gpt-4-0613": "GPT-4", 
    "gpt-3.5-turbo-0613+reflexion": "GPT-3.5+reflexion",
    "gpt-3.5-turbo-0613+gpt-4-0613": "GPT-4, GPT-3.5",
    "gpt-4-0613+reflexion": "GPT-4+reflexion", 
    "l3_8b-gpt-3.5-turbo-0613-l3_70b-gpt4-0613": "gpt",
    "gpt-4-0613-5repeats-no-temp-incr": "GPT-4",
    "gpt-4-0613+gpt-4-0613": "GPT-4",
    "gpt-4-0613-5step": "GPT-4",
    # "gpt-3.5-turbo-0613-5repeats-no-temp-incr": "GPT-3.5",
    # "CL > GPT3.5 > GPT4": "CodeLlama"
}

data['model'] = data['model'].map(model_renames)

# Add model name to the strategy name
for i in range(data.shape[0]):
    if strategy_renames[data['strategy'][i]] == "":
        data.loc[i, 'strategy_renamed'] = data['model'][i]
    elif strategy_renames[data['strategy'][i]] == "Escalation":
        data.loc[i, 'strategy_renamed'] = "Escalation"
    else:
        data.loc[i, 'strategy_renamed'] = str(data['strategy_renamed'][i]) + " (" + str(data['model'][i]) + ")"
    #if strategy is ldb and model contains reflexion, then add reflexion to the strategy name
    if data['strategy'][i] == "ldb" and "reflexion" in data['model'][i]:
        data.loc[i, 'strategy_renamed'] = "LDB" + " (" + "Reflexion, " + str(data['model'][i]).replace("+reflexion", "") + ")"




# # Change colors of points based on strategy and model
# scatter_plot = sns.scatterplot(data=data, x='total_cost', y='accuracy', hue='strategy_renamed', palette=color_dict,
#                                 marker='o', s=200, legend=None)


# Group data by model and strategy, calculating mean and error bar ranges
grouped_data = data.groupby(['model', 'strategy_renamed']).agg(
    mean_accuracy=('accuracy', 'mean'),
    min_accuracy=('accuracy', 'min'),
    max_accuracy=('accuracy', 'max'),
    mean_cost=('total_cost', 'mean')
).reset_index()

# Calculate error bar values (max - mean and mean - min)
grouped_data['yerr_upper'] = grouped_data['max_accuracy'] - grouped_data['mean_accuracy']
grouped_data['yerr_lower'] = grouped_data['mean_accuracy'] - grouped_data['min_accuracy']


# Create the scatter plot with error bars
f, (ax, ax2) = plt.subplots(1,2, figsize=(12, 8), sharey=True, width_ratios=[2, 1.3])
f.subplots_adjust(wspace=0.03)

scatter_plot = sns.scatterplot(
    data=grouped_data, 
    x='mean_cost', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None,
    ax=ax,
    zorder=2
)
scatter_plot2 = sns.scatterplot(
    data=grouped_data, 
    x='mean_cost', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None,
    ax=ax2,
    zorder=2
)

# # change color of the error bars
# for i in range(len(grouped_data)):
#     plt.errorbar(
#         x=grouped_data['mean_cost'][i], 
#         y=grouped_data['mean_accuracy'][i], 
#         yerr=[[grouped_data['yerr_lower'][i]], [grouped_data['yerr_upper'][i]]], 
#         fmt='o',  # Use the same marker as the scatter plot
#         color=color_dict[grouped_data['strategy_renamed'][i]],  # Use the same color as the scatter plot
#         capsize=0,  # Add caps to the error bars
#         elinewidth=3  # Adjust error bar line width
#     )

# LEGEND
colors = [orange, green, blue]
labels = ['Complex agent', 'Baseline agent', 'Simple model']
# Create empty scatter plots as legend handles
legend_handles = []
for color in colors:
    handle = plt.scatter([], [], c=color, marker='o')
    legend_handles.append(handle)
plt.legend(handles=legend_handles, labels=labels, loc="lower right")

# Setting the title and labels
# plt.title('Accuracy vs. Cost per Model and Agent on HumanEval', fontsize=16, pad=15)
ax.set_ylabel('Accuracy', fontsize=14)
# set joint x-axis label
f.text(0.5, 0.05, 'Cost (USD, measured in April 2024)', ha='center', va='center', fontsize=14)
# remove the x-axis label from the second plot
ax2.set_xlabel('')
ax.set_xlabel('')
plt.grid(True)

# Setting the y-axis limits
plt.ylim(0.7, 1)
ax.set_xlim(0, 19)
ax2.set_xlim(353, 365)
# plt.xscale('log', base=10)

# plot ticks on x axis every 5 units
ax.set_xticks([0,5,10,15])
ax2.set_xticks([360, 365])

ax.grid(False)
ax2.grid(False)

d = .02  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1 - d, 1 + d), (1 - d, 1 + d), zorder=3, **kwargs)     # top-left diagonal
ax.plot((1 - d, 1 + d), (-d, +d), zorder=3, **kwargs)  # top-right diagonal

d = .02
kwargs.update(transform=ax2.transAxes, color='k', clip_on=False)  # switch to the bottom axes
ax2.plot((-d-0.008, +d+0.008), (- d, + d), zorder=3, **kwargs)  # bottom-left diagonal
ax2.plot((- d-0.008, + d+0.008), (1 - d, 1 + d), zorder=3,**kwargs)  # bottom-right diagonal

ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

# Define the points for the Pareto frontier line
# pareto_color = "black"
# pareto_x = [0.041736, 0.418097, 3.883992]
# pareto_y = [0.752439, 0.875610, 0.906098]
# ax.plot(pareto_x, pareto_y, linestyle='dashed', color=pareto_color, zorder=1, linewidth=1, dashes=(10, 4))
# ax.text(pareto_x[1]+0.015, pareto_y[1]+0.005, 'Pareto frontier', fontsize=12, color=pareto_color, ha='left', va='bottom', rotation=32) # log scale
# plt.text(pareto_x[0]+0.022, pareto_y[0]+0.035, 'Pareto frontier', fontsize=12, color=pareto_color, ha='left', va='bottom', rotation=54)

data = grouped_data
# Implementing label adjustments using simple lines
for i in range(data.shape[0]):
    annotation_text = data.strategy_renamed[i]
    x = data.mean_cost[i]
    y = data.mean_accuracy[i]
    if data.strategy_renamed[i] == "Escalation":
        xytext = (60, -30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-3.5":
        xytext = (60, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-3.5)":
        xytext = (90, -30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-3.5)":
        xytext = (110, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-4)":
        xytext = (90, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-4)":
        xytext = (10, -30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-3.5)":
        xytext = (110, -30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4)":
        xytext = (70, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4, GPT-3.5)":
        xytext = (130, -17)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4)":
        xytext = (90, 25)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4-1step)":
        xytext = (60, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Retry (GPT-4)":
        xytext = (110,10)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-4":
        xytext = (50,-20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LATS (GPT-3.5)":
        xytext = (70,-20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LATS (GPT-4)":
        xytext = (0,-20)  # "Escalation" above the point
        ha = 'right'
    else:
        xytext = (60, -5)  # other strategies below the point to the right
        ha = 'right'

    scatter_plot.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))
    scatter_plot2.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))

plt.show()
# Out:
# /tmp/ipykernel_1777177/2869161131.py:124: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   handle = plt.scatter([], [], c=color, marker='o')

# %% [markdown]
# ### time

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

sns.set_style("whitegrid")
# Set the context for plotting 
sns.set_context("notebook", font_scale=1)  #

# Load the data
data = pd.read_csv('plot_data_0613.csv')


# Map the old strategy names to the new names
strategy_renames = {
    "ldb": "LDB",
    "lats": "LATS",
    "simple": "",
    "simple_boosting": "Escalation",
    "simple_incr_temp": "Warming",
    "reflexion": "Reflexion",
    "simple_repeat": "Retry"
}
data['strategy_renamed'] = data['strategy'].map(strategy_renames)

# Replace model names with more readable names
model_renames = {
    "gpt-3.5-turbo-0613": "GPT-3.5",
    "gpt-3.5-turbo-0613+gpt-3.5-turbo-0613": "GPT-3.5",
    "gpt-4-0613": "GPT-4", 
    "gpt-3.5-turbo-0613+reflexion": "GPT-3.5+reflexion",
    "gpt-3.5-turbo-0613+gpt-4-0613": "GPT-4, GPT-3.5",
    "gpt-4-0613+reflexion": "GPT-4+reflexion", 
    "l3_8b-gpt-3.5-turbo-0613-l3_70b-gpt4-0613": "gpt",
    "gpt-4-0613-5repeats-no-temp-incr": "GPT-4",
    "gpt-4-0613+gpt-4-0613": "GPT-4",
    "gpt-4-0613-5step": "GPT-4",
    # "gpt-3.5-turbo-0613-5repeats-no-temp-incr": "GPT-3.5",
    # "CL > GPT3.5 > GPT4": "CodeLlama"
}

data['model'] = data['model'].map(model_renames)

# Add model name to the strategy name
for i in range(data.shape[0]):
    if strategy_renames[data['strategy'][i]] == "":
        data.loc[i, 'strategy_renamed'] = data['model'][i]
    elif strategy_renames[data['strategy'][i]] == "Escalation":
        data.loc[i, 'strategy_renamed'] = "Escalation"
    else:
        data.loc[i, 'strategy_renamed'] = str(data['strategy_renamed'][i]) + " (" + str(data['model'][i]) + ")"
    #if strategy is ldb and model contains reflexion, then add reflexion to the strategy name
    if data['strategy'][i] == "ldb" and "reflexion" in data['model'][i]:
        data.loc[i, 'strategy_renamed'] = "LDB" + " (" + "Reflexion, " + str(data['model'][i]).replace("+reflexion", "") + ")"




# # Change colors of points based on strategy and model
# scatter_plot = sns.scatterplot(data=data, x='total_cost', y='accuracy', hue='strategy_renamed', palette=color_dict,
#                                 marker='o', s=200, legend=None)


# Group data by model and strategy, calculating mean and error bar ranges
grouped_data = data.groupby(['model', 'strategy_renamed']).agg(
    mean_accuracy=('accuracy', 'mean'),
    min_accuracy=('accuracy', 'min'),
    max_accuracy=('accuracy', 'max'),
    mean_time=('total_inference_time', 'mean')
).reset_index()

# Calculate error bar values (max - mean and mean - min)
grouped_data['yerr_upper'] = grouped_data['max_accuracy'] - grouped_data['mean_accuracy']
grouped_data['yerr_lower'] = grouped_data['mean_accuracy'] - grouped_data['min_accuracy']


# Create the scatter plot with error bars
f, (ax, ax2, ax3) = plt.subplots(1,3, figsize=(12, 8), sharey=True, width_ratios=[6, 2, 1.5])
f.subplots_adjust(wspace=0.03)

scatter_plot = sns.scatterplot(
    data=grouped_data, 
    x='mean_time', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None,
    ax=ax,
    zorder=2
)
scatter_plot2 = sns.scatterplot(
    data=grouped_data, 
    x='mean_time', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None,
    ax=ax2,
    zorder=2
)
scatter_plot3 = sns.scatterplot(
    data=grouped_data, 
    x='mean_time', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None,
    ax=ax3,
    zorder=2
)

# # change color of the error bars
# for i in range(len(grouped_data)):
#     plt.errorbar(
#         x=grouped_data['mean_cost'][i], 
#         y=grouped_data['mean_accuracy'][i], 
#         yerr=[[grouped_data['yerr_lower'][i]], [grouped_data['yerr_upper'][i]]], 
#         fmt='o',  # Use the same marker as the scatter plot
#         color=color_dict[grouped_data['strategy_renamed'][i]],  # Use the same color as the scatter plot
#         capsize=0,  # Add caps to the error bars
#         elinewidth=3  # Adjust error bar line width
#     )

# LEGEND
colors = [orange, green, blue]
labels = ['Complex agent', 'Baseline agent', 'Simple model']
# Create empty scatter plots as legend handles
legend_handles = []
for color in colors:
    handle = plt.scatter([], [], c=color, marker='o')
    legend_handles.append(handle)
plt.legend(handles=legend_handles, labels=labels, bbox_to_anchor=(1, 0.18))

# Setting the title and labels
# plt.title('Accuracy vs. Cost per Model and Agent on HumanEval', fontsize=16, pad=15)
ax.set_ylabel('Accuracy', fontsize=14)
# set joint x-axis label
f.text(0.5, 0.05, 'Time (Seconds, measured in April 2024)', ha='center', va='center', fontsize=14)
# remove the x-axis label from the second plot
ax.set_xlabel('')
ax2.set_xlabel('')
ax3.set_xlabel('')
plt.grid(True)

# Setting the y-axis limits
plt.ylim(0.7, 1)
ax.set_xlim(0, 6000)
ax2.set_xlim(38500, 40500)
ax3.set_xlim(44500, 46000)
# plt.xscale('log', base=10)

# plot ticks on x axis every 5 units
ax.set_xticks([0,1000,2000,3000,4000,5000])
ax2.set_xticks([39000,40000])
ax3.set_xticks([45000,46000])

ax.grid(False)
ax2.grid(False)
ax3.grid(False)

d = .02  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1 - d+0.008, 1 + d-0.008), (1 - d, 1 + d), zorder=3, **kwargs)     # top-left diagonal
ax.plot((1 - d+0.008, 1 + d-0.008), (-d, +d), zorder=3, **kwargs)  # top-right diagonal

kwargs = dict(transform=ax2.transAxes, color='k', clip_on=False)
ax2.plot((1 - d-0.015, 1 + d+0.015), (1 - d, 1 + d), zorder=3, **kwargs)     # top-left diagonal
ax2.plot((1 - d-0.015, 1 + d+0.015), (-d, +d), zorder=3, **kwargs)  # top-right diagonal

kwargs.update(transform=ax2.transAxes, color='k', clip_on=False)  # switch to the bottom axes
ax2.plot((-d-0.015, +d+0.015), (- d, + d), zorder=3, **kwargs)  # bottom-left diagonal
ax2.plot((- d-0.015, + d+0.015), (1 - d, 1 + d), zorder=3,**kwargs)  # bottom-right diagonal

kwargs.update(transform=ax3.transAxes, color='k', clip_on=False)  # switch to the bottom axes
ax3.plot((-d-0.025, +d+0.025), (- d, + d), zorder=3, **kwargs)  # bottom-left diagonal
ax3.plot((- d-0.025, + d+0.025), (1 - d, 1 + d), zorder=3,**kwargs)  # bottom-right diagonal

ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax3.spines['left'].set_visible(False)

# Define the points for the Pareto frontier line
# pareto_color = "black"
# pareto_x = [326.559755, 553.508508, 2772.993986]
# pareto_y = [0.739024, 0.85, 0.931707]
# ax.plot(pareto_x, pareto_y, linestyle='dashed', color=pareto_color, zorder=1, linewidth=1, dashes=(10, 4))
# ax.text(pareto_x[1]+0.01, pareto_y[1]+0.006, 'Pareto frontier', fontsize=12, color=pareto_color, ha='left', va='bottom', rotation=33) # log scale
# plt.text(pareto_x[0]+0.022, pareto_y[0]+0.035, 'Pareto frontier', fontsize=12, color=pareto_color, ha='left', va='bottom', rotation=54)


data = grouped_data
# Implementing label adjustments using simple lines
for i in range(data.shape[0]):
    annotation_text = data.strategy_renamed[i]
    x = data.mean_time[i]
    y = data.mean_accuracy[i]
    if data.strategy_renamed[i] == "Escalation":
        xytext = (60, -30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-3.5":
        xytext = (60, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-3.5)":
        xytext = (70, -25)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-3.5)":
        xytext = (110, -25)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-4)":
        xytext = (90, -25)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-4)":
        xytext = (90, -25)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-3.5)":
        xytext = (100, -25)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4)":
        xytext = (70, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4, GPT-3.5)":
        xytext = (120, -17)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4)":
        xytext = (20, 25)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4-1step)":
        xytext = (60, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Retry (GPT-4)":
        xytext = (110,20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-4":
        xytext = (40,-20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LATS (GPT-3.5)":
        xytext = (60,20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LATS (GPT-4)":
        xytext = (20,-20)  # "Escalation" above the point
        ha = 'right'
    else:
        xytext = (60, -5)  # other strategies below the point to the right
        ha = 'right'

    scatter_plot.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))
    scatter_plot2.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))
    scatter_plot3.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))

plt.show()
# Out:
# /tmp/ipykernel_1777177/1622911900.py:136: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   handle = plt.scatter([], [], c=color, marker='o')

# %% [markdown]
# ## with LATS full y scale

# %% [markdown]
# ### 0409

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

sns.set_style("whitegrid")
# Set the context for plotting 
sns.set_context("notebook", font_scale=1)  #

# Load the data
data = pd.read_csv('plot_data_0409.csv')


# Map the old strategy names to the new names
strategy_renames = {
    "ldb": "LDB",
    "lats": "LATS",
    "simple": "",
    "simple_boosting": "Escalation",
    "simple_incr_temp": "Warming",
    "reflexion": "Reflexion",
    "simple_repeat": "Retry"
}
data['strategy_renamed'] = data['strategy'].map(strategy_renames)

# Replace model names with more readable names
model_renames = {
    "gpt-3.5-turbo-0125": "GPT-3.5",
    "gpt-3.5-turbo-0125+gpt-3.5-turbo-0125": "GPT-3.5",
    "gpt-4-turbo-2024-04-09": "GPT-4",
    "gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09": "GPT-4",
    "gpt-4-turbo-0125": "GPT-4",
    "l3_8b-gpt35-l3_70b-gpt4": "gpt",
    "l3_8b-gpt35-l3_70b-gpt4-0409": "gpt",
    "gpt-4-turbo-0125": "GPT-4",
    "gpt-4-turbo-0409-5step": "GPT-4",
     "gpt-4-turbo-0409-1step": "GPT-4-1step",
     "gpt-4-turbo-0125-8repeats-no-temp-incr": "GPT-4",
     "gpt-4-turbo-2024-04-09+reflexion": "GPT-4+reflexion",
     "gpt-3.5-turbo-0125+reflexion": "GPT-3.5+reflexion",
     "gpt-4-turbo-0409-5repeats-no-temp-incr": "GPT-4",
     "gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09": "GPT-4, GPT-3.5",
    # "CL > GPT3.5 > GPT4": "CodeLlama"
}

data['model'] = data['model'].map(model_renames)

# Add model name to the strategy name
for i in range(data.shape[0]):
    if strategy_renames[data['strategy'][i]] == "":
        data.loc[i, 'strategy_renamed'] = data['model'][i]
    elif strategy_renames[data['strategy'][i]] == "Escalation":
        data.loc[i, 'strategy_renamed'] = "Escalation"
    else:
        data.loc[i, 'strategy_renamed'] = str(data['strategy_renamed'][i]) + " (" + str(data['model'][i]) + ")"
    #if strategy is ldb and model contains reflexion, then add reflexion to the strategy name
    if data['strategy'][i] == "ldb" and "reflexion" in data['model'][i]:
        data.loc[i, 'strategy_renamed'] = "LDB" + " (" + "Reflexion, " + str(data['model'][i]).replace("+reflexion", "") + ")"




# # Change colors of points based on strategy and model
# scatter_plot = sns.scatterplot(data=data, x='total_cost', y='accuracy', hue='strategy_renamed', palette=color_dict,
#                                 marker='o', s=200, legend=None)


# Group data by model and strategy, calculating mean and error bar ranges
grouped_data = data.groupby(['model', 'strategy_renamed']).agg(
    mean_accuracy=('accuracy', 'mean'),
    min_accuracy=('accuracy', 'min'),
    max_accuracy=('accuracy', 'max'),
    mean_cost=('total_cost', 'mean')
).reset_index()

# Calculate error bar values (max - mean and mean - min)
grouped_data['yerr_upper'] = grouped_data['max_accuracy'] - grouped_data['mean_accuracy']
grouped_data['yerr_lower'] = grouped_data['mean_accuracy'] - grouped_data['min_accuracy']


# Create the scatter plot with error bars
plt.figure(figsize=(12, 8))
scatter_plot = sns.scatterplot(
    data=grouped_data, 
    x='mean_cost', 
    y='mean_accuracy', 
    hue='strategy_renamed', 
    palette=color_dict, 
    marker='o', 
    s=100, 
    legend=None
)


# LEGEND
colors = [orange, green, blue]
labels = ['Complex agent', 'Baseline agent', 'Zero-shot model']
# Create empty scatter plots as legend handles
legend_handles = []
for color in colors:
    handle = plt.scatter([], [], c=color, marker='o')
    legend_handles.append(handle)
plt.legend(handles=legend_handles, labels=labels, loc="lower right")

# Setting the title and labels
# plt.title('Accuracy vs. Cost per Model and Agent on HumanEval', fontsize=16, pad=15)
plt.xlabel('Cost (USD, measured in April 2024)', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.grid(True)


# Setting the y-axis limits
plt.ylim(0, 1)
plt.xlim(0,)
# plt.xscale('log', base=10)

plt.grid(False)

data = grouped_data
# Implementing label adjustments using simple lines
for i in range(data.shape[0]):
    annotation_text = data.strategy_renamed[i]
    x = data.mean_cost[i]
    y = data.mean_accuracy[i]
    if data.strategy_renamed[i] == "Escalation":
        xytext = (75, -10)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-3.5":
        xytext = (50, -60)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-3.5)":
        xytext = (95, -50)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-3.5)":
        xytext = (110, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Reflexion (GPT-4)":
        xytext = (230, -40)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-4)":
        xytext = (210, 5)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (Reflexion, GPT-3.5)":
        xytext = (240, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4)":
        xytext = (120, 20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LDB (GPT-4, GPT-3.5)":
        xytext = (250, -15)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4)":
        xytext = (110, 40)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Warming (GPT-4-1step)":
        xytext = (60, -20)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "Retry (GPT-4)":
        xytext = (180,-5)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "GPT-4":
        xytext = (-20,0)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LATS (GPT-3.5)":
        xytext = (100,-30)  # "Escalation" above the point
        ha = 'right'
    elif data.strategy_renamed[i] == "LATS (GPT-4)":
        xytext = (0,-20)  # "Escalation" above the point
        ha = 'right'
    else:
        xytext = (60, -5)  # other strategies below the point to the right
        ha = 'right'

    scatter_plot.annotate(annotation_text, xy=(x, y), xycoords='data',
                          xytext=xytext, textcoords='offset points',
                          size=12, ha=ha, va='center', color='black',
                          arrowprops=dict(arrowstyle="-", color='gray'))

plt.show()
# Out:
# /tmp/ipykernel_1777177/2034682720.py:101: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   handle = plt.scatter([], [], c=color, marker='o')

# %% [markdown]
# ## Variance analysis

# %% [markdown]
# ### 0409

# %%
import os
root_directories = ['LLMDebugger/output_data/simple', 
                        'LLMDebugger/output_data/ldb', 
                        'LLMDebugger/output_data/simple_boosting',
                        "reflexion/output_data",
                        "LLMDebugger/output_data/simple_incr_temp",
                        "LLMDebugger/output_data/simple_repeat",
                        "LanguageAgentTreeSearch/output_data/lats"
                        ]

per_task_stats_dict = {}
for root_dir in root_directories:
    for dirpath, dirnames, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.endswith(".log"):
                log_path = os.path.join(dirpath, filename)
                print("next log: ", log_path)
                run_name = log_path.split('/')[-2]
                model_name = log_path.split('/')[-3]
                strategy_name = log_path.split('/')[-5]
                print(strategy_name)
                aggregate_stats, per_task_stats = analyze_log(log_path)

                # if strategy is ldb then add task_stats of seed model
                if strategy_name == "ldb":
                    print("LDB model, adding seed model stats")
                    seed_model_name = model_name.split('+')[1]
                    main_model_name = model_name.split('+')[0]
                    if "reflexion" in model_name:
                        print("Reflexion seed, adding reflexion model stats")
                        print("main model: ", main_model_name)
                        if main_model_name == "gpt-3.5-turbo-0125": 
                            seed_log_path = os.path.join("reflexion/output_data/reflexion/humaneval", "gpt-4-turbo-2024-04-09", run_name, "humaneval-py._reflexion_" + "gpt-4-turbo-2024-04-09" + ".log")
                        elif main_model_name == "gpt-3.5-turbo-0613":
                            seed_log_path = os.path.join("reflexion/output_data/reflexion/humaneval", "gpt-4-0613", run_name, "humaneval-py._reflexion_" + "gpt-4-0613" + ".log")
                        else:
                            seed_log_path = os.path.join("reflexion/output_data/reflexion/humaneval", main_model_name, run_name, "humaneval-py._reflexion_" + main_model_name + ".log")
                        print("Reflexion seed, adding reflexion model stats: ", seed_log_path)
                        seed_aggregate_stats, seed_per_task_stats = analyze_log(seed_log_path)
                        per_task_stats.extend(seed_per_task_stats)
                    else:
                        seed_log_path = os.path.join("LLMDebugger/output_data/simple/humaneval", seed_model_name, run_name, "probs._simple_" + seed_model_name + ".log")
                        print("Simple seed, adding simple seed stats:", seed_log_path)
                        seed_aggregate_stats, seed_per_task_stats = analyze_log(seed_log_path)
                        per_task_stats.extend(seed_per_task_stats)
                per_task_stats_dict[strategy_name+"__"+model_name] = per_task_stats
# Out:
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-1106/run1/probs._simple_gpt-3.5-turbo-1106.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-1106/run2/probs._simple_gpt-3.5-turbo-1106.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-1106/run3/probs._simple_gpt-3.5-turbo-1106.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-1106/run4/probs._simple_gpt-3.5-turbo-1106.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-1106/run5/probs._simple_gpt-3.5-turbo-1106.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run1/probs._simple_gpt-4-0613.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run2/probs._simple_gpt-4-0613.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run3/probs._simple_gpt-4-0613.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run4/probs._simple_gpt-4-0613.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run5/probs._simple_gpt-4-0613.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0613/run1/probs._simple_gpt-3.5-turbo-0613.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0613/run2/probs._simple_gpt-3.5-turbo-0613.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0613/run3/probs._simple_gpt-3.5-turbo-0613.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0613/run4/probs._simple_gpt-3.5-turbo-0613.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0613/run5/probs._simple_gpt-3.5-turbo-0613.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run1/probs._simple_gpt-4-turbo-2024-04-09.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run2/probs._simple_gpt-4-turbo-2024-04-09.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run3/probs._simple_gpt-4-turbo-2024-04-09.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run4/probs._simple_gpt-4-turbo-2024-04-09.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run5/probs._simple_gpt-4-turbo-2024-04-09.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0125/run1/probs._simple_gpt-3.5-turbo-0125.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0125/run2/probs._simple_gpt-3.5-turbo-0125.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0125/run3/probs._simple_gpt-3.5-turbo-0125.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0125/run4/probs._simple_gpt-3.5-turbo-0125.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0125/run5/probs._simple_gpt-3.5-turbo-0125.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-1106-preview/run1/probs._simple_gpt-4-1106-preview.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-1106-preview/run2/probs._simple_gpt-4-1106-preview.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-1106-preview/run3/probs._simple_gpt-4-1106-preview.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-1106-preview/run4/probs._simple_gpt-4-1106-preview.log
# simple
# next log:  LLMDebugger/output_data/simple/humaneval/gpt-4-1106-preview/run5/probs._simple_gpt-4-1106-preview.log
# simple
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-0613+gpt-4-0613/run1/probs._ldb_gpt-4-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run1/probs._simple_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-0613+gpt-4-0613/run2/probs._ldb_gpt-4-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run2/probs._simple_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-0613+gpt-4-0613/run3/probs._ldb_gpt-4-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run3/probs._simple_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-0613+gpt-4-0613/run4/probs._ldb_gpt-4-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run4/probs._simple_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-0613+gpt-4-0613/run5/probs._ldb_gpt-4-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run5/probs._simple_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09/run1/probs._ldb_gpt-4-turbo-2024-04-09.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run1/probs._simple_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09/run2/probs._ldb_gpt-4-turbo-2024-04-09.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run2/probs._simple_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09/run3/probs._ldb_gpt-4-turbo-2024-04-09.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run3/probs._simple_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09/run4/probs._ldb_gpt-4-turbo-2024-04-09.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run4/probs._simple_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09/run5/probs._ldb_gpt-4-turbo-2024-04-09.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run5/probs._simple_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-1106-preview+gpt-4-1106-preview/run1/probs._ldb_gpt-4-1106-preview.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-1106-preview/run1/probs._simple_gpt-4-1106-preview.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-1106-preview+gpt-4-1106-preview/run2/probs._ldb_gpt-4-1106-preview.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-1106-preview/run2/probs._simple_gpt-4-1106-preview.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-1106-preview+gpt-4-1106-preview/run3/probs._ldb_gpt-4-1106-preview.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-1106-preview/run3/probs._simple_gpt-4-1106-preview.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-1106-preview+gpt-4-1106-preview/run4/probs._ldb_gpt-4-1106-preview.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-1106-preview/run4/probs._simple_gpt-4-1106-preview.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-1106-preview+gpt-4-1106-preview/run5/probs._ldb_gpt-4-1106-preview.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-1106-preview/run5/probs._simple_gpt-4-1106-preview.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-0613+reflexion/run1/probs._ldb_gpt-4-0613.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-4-0613
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run1/humaneval-py._reflexion_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-0613+reflexion/run2/probs._ldb_gpt-4-0613.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-4-0613
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run2/humaneval-py._reflexion_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-0613+reflexion/run3/probs._ldb_gpt-4-0613.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-4-0613
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run3/humaneval-py._reflexion_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-0613+reflexion/run4/probs._ldb_gpt-4-0613.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-4-0613
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run4/humaneval-py._reflexion_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-0613+reflexion/run5/probs._ldb_gpt-4-0613.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-4-0613
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run5/humaneval-py._reflexion_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-turbo-2024-04-09+reflexion/run1/probs._ldb_gpt-4-turbo-2024-04-09.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-4-turbo-2024-04-09
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run1/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-turbo-2024-04-09+reflexion/run2/probs._ldb_gpt-4-turbo-2024-04-09.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-4-turbo-2024-04-09
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run2/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-turbo-2024-04-09+reflexion/run3/probs._ldb_gpt-4-turbo-2024-04-09.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-4-turbo-2024-04-09
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run3/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-turbo-2024-04-09+reflexion/run4/probs._ldb_gpt-4-turbo-2024-04-09.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-4-turbo-2024-04-09
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run4/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-4-turbo-2024-04-09+reflexion/run5/probs._ldb_gpt-4-turbo-2024-04-09.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-4-turbo-2024-04-09
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run5/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+reflexion/run1/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-3.5-turbo-0125
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run1/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+reflexion/run2/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-3.5-turbo-0125
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run2/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+reflexion/run3/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-3.5-turbo-0125
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run3/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+reflexion/run4/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-3.5-turbo-0125
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run4/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+reflexion/run5/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-3.5-turbo-0125
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run5/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09/run1/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run1/probs._simple_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09/run2/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run2/probs._simple_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09/run3/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run3/probs._simple_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09/run4/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run4/probs._simple_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09/run5/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-turbo-2024-04-09/run5/probs._simple_gpt-4-turbo-2024-04-09.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+gpt-4-0613/run1/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run1/probs._simple_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+gpt-4-0613/run2/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run2/probs._simple_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+gpt-4-0613/run3/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run3/probs._simple_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+gpt-4-0613/run4/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run4/probs._simple_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+gpt-4-0613/run5/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-4-0613/run5/probs._simple_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+reflexion/run1/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-3.5-turbo-0613
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run1/humaneval-py._reflexion_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+reflexion/run2/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-3.5-turbo-0613
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run2/humaneval-py._reflexion_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+reflexion/run3/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-3.5-turbo-0613
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run3/humaneval-py._reflexion_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+reflexion/run4/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-3.5-turbo-0613
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run4/humaneval-py._reflexion_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+reflexion/run5/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Reflexion seed, adding reflexion model stats
# main model:  gpt-3.5-turbo-0613
# Reflexion seed, adding reflexion model stats:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run5/humaneval-py._reflexion_gpt-4-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-1106+gpt-3.5-turbo-1106/run1/probs._ldb_gpt-3.5-turbo-1106.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-1106/run1/probs._simple_gpt-3.5-turbo-1106.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-1106+gpt-3.5-turbo-1106/run2/probs._ldb_gpt-3.5-turbo-1106.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-1106/run2/probs._simple_gpt-3.5-turbo-1106.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-1106+gpt-3.5-turbo-1106/run3/probs._ldb_gpt-3.5-turbo-1106.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-1106/run3/probs._simple_gpt-3.5-turbo-1106.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-1106+gpt-3.5-turbo-1106/run4/probs._ldb_gpt-3.5-turbo-1106.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-1106/run4/probs._simple_gpt-3.5-turbo-1106.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-1106+gpt-3.5-turbo-1106/run5/probs._ldb_gpt-3.5-turbo-1106.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-1106/run5/probs._simple_gpt-3.5-turbo-1106.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+gpt-3.5-turbo-0125/run1/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0125/run1/probs._simple_gpt-3.5-turbo-0125.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+gpt-3.5-turbo-0125/run2/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0125/run2/probs._simple_gpt-3.5-turbo-0125.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+gpt-3.5-turbo-0125/run3/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0125/run3/probs._simple_gpt-3.5-turbo-0125.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+gpt-3.5-turbo-0125/run4/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0125/run4/probs._simple_gpt-3.5-turbo-0125.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0125+gpt-3.5-turbo-0125/run5/probs._ldb_gpt-3.5-turbo-0125.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0125/run5/probs._simple_gpt-3.5-turbo-0125.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+gpt-3.5-turbo-0613/run1/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0613/run1/probs._simple_gpt-3.5-turbo-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+gpt-3.5-turbo-0613/run2/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0613/run2/probs._simple_gpt-3.5-turbo-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+gpt-3.5-turbo-0613/run3/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0613/run3/probs._simple_gpt-3.5-turbo-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+gpt-3.5-turbo-0613/run4/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0613/run4/probs._simple_gpt-3.5-turbo-0613.log
# next log:  LLMDebugger/output_data/ldb/humaneval/gpt-3.5-turbo-0613+gpt-3.5-turbo-0613/run5/probs._ldb_gpt-3.5-turbo-0613.log
# ldb
# LDB model, adding seed model stats
# Simple seed, adding simple seed stats: LLMDebugger/output_data/simple/humaneval/gpt-3.5-turbo-0613/run5/probs._simple_gpt-3.5-turbo-0613.log
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt35-l3_70b-gpt4/run1/probs._simple_boosting_run1.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt35-l3_70b-gpt4/run2/probs._simple_boosting_run2.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt35-l3_70b-gpt4/run3/probs._simple_boosting_run3.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt35-l3_70b-gpt4/run4/probs._simple_boosting_run4.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt35-l3_70b-gpt4/run5/probs._simple_boosting_run5.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/CodeLlama-34b-Instruct-hf/run1/probs._simple_boosting_CodeLlama-34b-Instruct-hf.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/CodeLlama-34b-Instruct-hf/run2/probs._simple_boosting_CodeLlama-34b-Instruct-hf.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/CodeLlama-34b-Instruct-hf/run3/probs._simple_boosting_CodeLlama-34b-Instruct-hf.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/CodeLlama-34b-Instruct-hf/run4/probs._simple_boosting_CodeLlama-34b-Instruct-hf.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/CodeLlama-34b-Instruct-hf/run5/probs._simple_boosting_CodeLlama-34b-Instruct-hf.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt-3.5-turbo-0613-l3_70b-gpt4-0613/run1/probs._simple_boosting_run1.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt-3.5-turbo-0613-l3_70b-gpt4-0613/run2/probs._simple_boosting_run2.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt-3.5-turbo-0613-l3_70b-gpt4-0613/run3/probs._simple_boosting_run3.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt-3.5-turbo-0613-l3_70b-gpt4-0613/run4/probs._simple_boosting_run4.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt-3.5-turbo-0613-l3_70b-gpt4-0613/run5/probs._simple_boosting_run5.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt35-l3_70b-gpt4-0409/run1/probs._simple_boosting_run1.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt35-l3_70b-gpt4-0409/run2/probs._simple_boosting_run2.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt35-l3_70b-gpt4-0409/run3/probs._simple_boosting_run3.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt35-l3_70b-gpt4-0409/run4/probs._simple_boosting_run4.log
# simple_boosting
# next log:  LLMDebugger/output_data/simple_boosting/humaneval/l3_8b-gpt35-l3_70b-gpt4-0409/run5/probs._simple_boosting_run5.log
# simple_boosting
# next log:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run1/humaneval-py._reflexion_gpt-4-0613.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run2/humaneval-py._reflexion_gpt-4-0613.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run3/humaneval-py._reflexion_gpt-4-0613.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run4/humaneval-py._reflexion_gpt-4-0613.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-4-0613/run5/humaneval-py._reflexion_gpt-4-0613.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-3.5-turbo-0613/run1/humaneval-py._reflexion_gpt-3.5-turbo-0613.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-3.5-turbo-0613/run2/humaneval-py._reflexion_gpt-3.5-turbo-0613.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-3.5-turbo-0613/run3/humaneval-py._reflexion_gpt-3.5-turbo-0613.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-3.5-turbo-0613/run4/humaneval-py._reflexion_gpt-3.5-turbo-0613.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-3.5-turbo-0613/run5/humaneval-py._reflexion_gpt-3.5-turbo-0613.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run1/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run2/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run3/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run4/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09/run5/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09_6tests/run1/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# reflexion
# next log:  reflexion/output_data/reflexion/humaneval/gpt-4-turbo-2024-04-09_6tests/run2/humaneval-py._reflexion_gpt-4-turbo-2024-04-09.log
# reflexion
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-3.5-turbo-0613-5step/run1/probs._simple_incr_temp_gpt-3.5-turbo-0613.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-3.5-turbo-0613-5step/run2/probs._simple_incr_temp_gpt-3.5-turbo-0613.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-3.5-turbo-0613-5step/run3/probs._simple_incr_temp_gpt-3.5-turbo-0613.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-3.5-turbo-0613-5step/run4/probs._simple_incr_temp_gpt-3.5-turbo-0613.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-3.5-turbo-0613-5step/run5/probs._simple_incr_temp_gpt-3.5-turbo-0613.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-turbo-0409-5step/run1/probs._simple_incr_temp_gpt-4-turbo-2024-04-09.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-turbo-0409-5step/run2/probs._simple_incr_temp_gpt-4-turbo-2024-04-09.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-turbo-0409-5step/run3/probs._simple_incr_temp_gpt-4-turbo-2024-04-09.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-turbo-0409-5step/run4/probs._simple_incr_temp_gpt-4-turbo-2024-04-09.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-turbo-0409-5step/run5/probs._simple_incr_temp_gpt-4-turbo-2024-04-09.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-turbo-0409-1step/run1/probs._simple_incr_temp_gpt-4-turbo-2024-04-09.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-0613-5step/run1/probs._simple_incr_temp_gpt-4-0613.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-0613-5step/run2/probs._simple_incr_temp_gpt-4-0613.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-0613-5step/run3/probs._simple_incr_temp_gpt-4-0613.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-0613-5step/run4/probs._simple_incr_temp_gpt-4-0613.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-0613-5step/run5/probs._simple_incr_temp_gpt-4-0613.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-turbo-0409-5repeats-0.5temp/run1/probs._simple_incr_temp_gpt-4-turbo-2024-04-09.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-turbo-0409-5repeats-0.5temp/run2/probs._simple_incr_temp_gpt-4-turbo-2024-04-09.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-turbo-0409-5repeats-0.5temp/run3/probs._simple_incr_temp_gpt-4-turbo-2024-04-09.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-turbo-0409-5repeats-0.5temp/run4/probs._simple_incr_temp_gpt-4-turbo-2024-04-09.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_incr_temp/humaneval/gpt-4-turbo-0409-5repeats-0.5temp/run5/probs._simple_incr_temp_gpt-4-turbo-2024-04-09.log
# simple_incr_temp
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-0613-5repeats-no-temp-incr/run1/probs._simple_repeat_gpt-4-0613.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-0613-5repeats-no-temp-incr/run2/probs._simple_repeat_gpt-4-0613.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-0613-5repeats-no-temp-incr/run3/probs._simple_repeat_gpt-4-0613.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-0613-5repeats-no-temp-incr/run4/probs._simple_repeat_gpt-4-0613.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-0613-5repeats-no-temp-incr/run5/probs._simple_repeat_gpt-4-0613.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-turbo-0409-5repeats-no-temp-incr/run1/probs._simple_repeat_gpt-4-turbo-2024-04-09.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-turbo-0409-5repeats-no-temp-incr/run2/probs._simple_repeat_gpt-4-turbo-2024-04-09.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-turbo-0409-5repeats-no-temp-incr/run3/probs._simple_repeat_gpt-4-turbo-2024-04-09.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-turbo-0409-5repeats-no-temp-incr/run4/probs._simple_repeat_gpt-4-turbo-2024-04-09.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-turbo-0409-5repeats-no-temp-incr/run5/probs._simple_repeat_gpt-4-turbo-2024-04-09.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-turbo-0409-8repeats-no-temp-incr/run1/probs._simple_repeat_gpt-4-turbo-2024-04-09.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-turbo-0409-8repeats-no-temp-incr/run2/probs._simple_repeat_gpt-4-turbo-2024-04-09.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-turbo-0409-8repeats-no-temp-incr/run3/probs._simple_repeat_gpt-4-turbo-2024-04-09.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-turbo-0409-8repeats-no-temp-incr/run4/probs._simple_repeat_gpt-4-turbo-2024-04-09.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-turbo-0409-8repeats-no-temp-incr/run5/probs._simple_repeat_gpt-4-turbo-2024-04-09.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-3.5-turbo-0613-5repeats-no-temp-incr/run1/probs._simple_repeat_gpt-3.5-turbo-0613.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-3.5-turbo-0613-5repeats-no-temp-incr/run2/probs._simple_repeat_gpt-3.5-turbo-0613.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-3.5-turbo-0613-5repeats-no-temp-incr/run3/probs._simple_repeat_gpt-3.5-turbo-0613.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-3.5-turbo-0613-5repeats-no-temp-incr/run4/probs._simple_repeat_gpt-3.5-turbo-0613.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-3.5-turbo-0613-5repeats-no-temp-incr/run5/probs._simple_repeat_gpt-3.5-turbo-0613.log
# simple_repeat
# next log:  LLMDebugger/output_data/simple_repeat/humaneval/gpt-4-turbo-0125-8repeats-no-temp-incr/run1/probs._simple_repeat_gpt-4.log
# simple_repeat
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-4-0613/run1/humaneval-py._mcts_gpt-4-0613.log
# lats
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-3.5-turbo-0613/run1/humaneval-py._mcts_gpt-3.5-turbo-0613.log
# lats
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-4-turbo-2024-04-09/run1/humaneval-py._mcts_gpt-4-turbo-2024-04-09.log
# lats
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-4-turbo-2024-04-09/run2/humaneval-py._mcts_gpt-4-turbo-2024-04-09.log
# lats
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-4-turbo-2024-04-09/run3/humaneval-py._mcts_gpt-4-turbo-2024-04-09.log
# lats
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-4-turbo-2024-04-09/run4/humaneval-py._mcts_gpt-4-turbo-2024-04-09.log
# lats
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-4-turbo-2024-04-09/run5/humaneval-py._mcts_gpt-4-turbo-2024-04-09.log
# lats
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-3.5-turbo-0125/run1/humaneval-py._mcts_gpt-3.5-turbo-0125.log
# lats
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-3.5-turbo-0125/run2/humaneval-py._mcts_gpt-3.5-turbo-0125.log
# lats
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-3.5-turbo-0125/run3/humaneval-py._mcts_gpt-3.5-turbo-0125.log
# lats
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-3.5-turbo-0125/run4/humaneval-py._mcts_gpt-3.5-turbo-0125.log
# lats
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-3.5-turbo-0125/run5/humaneval-py._mcts_gpt-3.5-turbo-0125.log
# lats
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-3.5-turbo-0125_gpt4_0125backend/run1/humaneval-py._mcts_gpt-3.5-turbo-0125.log
# lats
# next log:  LanguageAgentTreeSearch/output_data/lats/humaneval/gpt-4-turbo-0125/run1/humaneval-py._mcts_gpt-4-turbo-0125.log
# lats

# %%
import re
import numpy as np
result = {}
for idx in per_task_stats_dict.keys():
    print("Next idx: ", idx)
    temp_task = {}

    if len(per_task_stats_dict[idx]) != 164:
        for task in per_task_stats_dict[idx]:
            # Extract the integer part of the task_id using regular expressions
            task_id_int = int(re.search(r'\d+', task['task_id']).group())
            
            if task_id_int not in temp_task:
                temp_task[task_id_int] = {'cost': 0, 'inference_time': 0}
            
            temp_task[task_id_int]['cost'] += task['cost']
            temp_task[task_id_int]['inference_time'] += task['total_inference_time']

        costs = [task['cost'] for task in temp_task.values()]

        inference_times = [task['inference_time'] for task in temp_task.values()]
    else:
        costs = [task['cost'] for task in per_task_stats_dict[idx]]
        inference_times = [task['total_inference_time'] for task in per_task_stats_dict[idx]]

    mean_cost = statistics.mean(costs)
    std_cost = statistics.stdev(costs)
    percentile_95_cost = np.percentile(costs, 95)
    max_cost = max(costs)

    mean_inference_time = statistics.mean(inference_times)
    std_inference_time = statistics.stdev(inference_times)
    percentile_95_inference_time = np.percentile(inference_times, 95)
    max_inference_time = max(inference_times)


    result[idx] = {'mean_cost': mean_cost, 
                   'std_cost': std_cost, 
                    'percentile_95_cost': percentile_95_cost,
                    'max_cost': max_cost,
                   'mean_inference_time': mean_inference_time, 
                   'std_inference_time': std_inference_time,
                   'percentile_95_inference_time': percentile_95_inference_time,
                   'max_inference_time': max_inference_time}
# Out:
# Next idx:  simple__gpt-3.5-turbo-1106
# Next idx:  simple__gpt-4-0613
# Next idx:  simple__gpt-3.5-turbo-0613
# Next idx:  simple__gpt-4-turbo-2024-04-09
# Next idx:  simple__gpt-3.5-turbo-0125
# Next idx:  simple__gpt-4-1106-preview
# Next idx:  ldb__gpt-4-0613+gpt-4-0613
# Next idx:  ldb__gpt-4-turbo-2024-04-09+gpt-4-turbo-2024-04-09
# Next idx:  ldb__gpt-4-1106-preview+gpt-4-1106-preview
# Next idx:  ldb__gpt-4-0613+reflexion
# Next idx:  ldb__gpt-4-turbo-2024-04-09+reflexion
# Next idx:  ldb__gpt-3.5-turbo-0125+reflexion
# Next idx:  ldb__gpt-3.5-turbo-0125+gpt-4-turbo-2024-04-09
# Next idx:  ldb__gpt-3.5-turbo-0613+gpt-4-0613
# Next idx:  ldb__gpt-3.5-turbo-0613+reflexion
# Next idx:  ldb__gpt-3.5-turbo-1106+gpt-3.5-turbo-1106
# Next idx:  ldb__gpt-3.5-turbo-0125+gpt-3.5-turbo-0125
# Next idx:  ldb__gpt-3.5-turbo-0613+gpt-3.5-turbo-0613
# Next idx:  simple_boosting__l3_8b-gpt35-l3_70b-gpt4
# Next idx:  simple_boosting__CodeLlama-34b-Instruct-hf
# Next idx:  simple_boosting__l3_8b-gpt-3.5-turbo-0613-l3_70b-gpt4-0613
# Next idx:  simple_boosting__l3_8b-gpt35-l3_70b-gpt4-0409
# Next idx:  reflexion__gpt-4-0613
# Next idx:  reflexion__gpt-3.5-turbo-0613
# Next idx:  reflexion__gpt-4-turbo-2024-04-09
# Next idx:  reflexion__gpt-4-turbo-2024-04-09_6tests
# Next idx:  simple_incr_temp__gpt-3.5-turbo-0613-5step
# Next idx:  simple_incr_temp__gpt-4-turbo-0409-5step
# Next idx:  simple_incr_temp__gpt-4-turbo-0409-1step
# Next idx:  simple_incr_temp__gpt-4-0613-5step
# Next idx:  simple_incr_temp__gpt-4-turbo-0409-5repeats-0.5temp
# Next idx:  simple_repeat__gpt-4-0613-5repeats-no-temp-incr
# Next idx:  simple_repeat__gpt-4-turbo-0409-5repeats-no-temp-incr
# Next idx:  simple_repeat__gpt-4-turbo-0409-8repeats-no-temp-incr
# Next idx:  simple_repeat__gpt-3.5-turbo-0613-5repeats-no-temp-incr
# Next idx:  simple_repeat__gpt-4-turbo-0125-8repeats-no-temp-incr
# Next idx:  lats__gpt-4-0613
# Next idx:  lats__gpt-3.5-turbo-0613
# Next idx:  lats__gpt-4-turbo-2024-04-09
# Next idx:  lats__gpt-3.5-turbo-0125
# Next idx:  lats__gpt-3.5-turbo-0125_gpt4_0125backend
# Next idx:  lats__gpt-4-turbo-0125

# %%
# plot result dict as png table
result

# %%
import matplotlib.pyplot as plt

# Assuming 'result' is your dictionary with model performance data
models = list(result.keys())
cost_means = [result[model]['mean_cost'] for model in models]
cost_stds = [result[model]['std_cost'] for model in models]
time_means = [result[model]['mean_inference_time'] for model in models]
time_stds = [result[model]['std_inference_time'] for model in models]

import matplotlib.pyplot as plt
import numpy as np

# Data (Dummy values, real values should be based on the data analysis)
categories = result.keys()

# Create a figure and a set of subplots
fig, ax = plt.subplots(figsize=(12, 30))

# Create the main horizontal line at 0
ax.axvline(x=0, color='black', lw=2)

# Scatter plot
for i, (mean, std_dev) in enumerate(zip(cost_means, cost_stds)):
    ax.errorbar(mean, i, xerr=std_dev, fmt='o', color='blue' if mean < 0 else 'red', ecolor='black', elinewidth=3, capsize=0)

# Set labels
ax.set_yticks(np.arange(len(categories)))
ax.set_yticklabels(categories)

# Invert y axis to match the provided chart
ax.invert_yaxis()

# Remove xticks, as the provided chart doesn't have any
ax.xaxis.set_ticks_position('none') 

# Set the limits for x-axis to match the scale of the provided chart
ax.set_xlim(0, 0.2)

# Show grid
ax.grid(True, linestyle='--', linewidth=0.5)

# Display the plot
plt.show()
